# %% [markdown]
# # **Rule-Based Algorithm**
# ### Group 1 - Detection of Negation and Uncertainty
#
# - Marino Oliveros Blanco NIU:1668563
# - Pere Mayol Carbonell NIU:1669503
# -
# -

# %% [markdown]
# **Data loading**

# %%
# Libraries
import json
import re
from langdetect import detect # Library for language detection
from spellchecker import SpellChecker
import spacy
import string
from unidecode import unidecode

# %% [markdown]
# ### **Pre-processing**
# - Removing redacted entries
# - Removing language mixes
# - Solving misspelled words
# - Removing patient information
# - Tokenizing

# %%
# Load language models for Spanish and Catalan
nlp_es = spacy.load("es_core_news_sm")
nlp_ca = spacy.load("ca_core_news_sm")

def remove_patient_info(tokens):
    # Define patterns to match patient information identifiers
    patterns = [
        r'nº\s?historia\s?clinica:',
        r'nºepisodi:',
        r'sexe:',
        r'data\s?de\s?naixement:',
        r'edat:',
        r'procedencia',
        r'servei\s?obstetricia',
        r'data\sd\'ingres',
        r'data\sd\'alta',
        r'ates\s?per',
        r'informe\sd\'alta\sd\'hospitalitzacio',
        r'motiu\sd\'ingres',
        r'nhc',
        r'lopd'
    ]
    # Join tokens into text for efficient pattern matching
    text = ' '.join([token[0] for token in tokens])
    # Remove tokens containing patient information identifiers
    for pattern in patterns:
        text = re.sub(pattern + '.*?(?=\\s|$)', '', text, flags=re.IGNORECASE)
    # Tokenize the modified text
    return tokenize_with_coordinates(text)



# 2 Remove Punctuation (Able to be turned ON/OFF)
def remove_punctuation(tokens):
    # Remove punctuation from token text
    tokens_without_punct = [(token[0].translate(str.maketrans('', '', string.punctuation)), token[1], token[2]) for token in tokens]
    return tokens_without_punct

# 3 Spell checking with language detection (Able to be turned ON/OFF)
def spell_check_and_lemmatize(tokens):
    # Join tokens into text
    text = ' '.join([token[0] for token in tokens])
    # Detect the language of the text
    language = detect(text)
    # Initialize spell checker
    spell = SpellChecker(language='es')  # As most of the text is in Spanish

    # Tokenize the text using the appropriate language model
    if language == 'ca':
        doc = nlp_ca(text)
    else:
        doc = nlp_es(text)

    # Correct misspelled words and lemmatize tokens
    corrected_tokens = []
    for token in doc:
        # Check if the token is a punctuation or whitespace
        if not token.is_punct and not token.is_space:
            # Get the corrected version of the token
            corrected_token = spell.correction(token.text)
            # Lemmatize the corrected token
            corrected_token_lemma = token.lemma_ if token.lemma_ != '-PRON-' else corrected_token
            corrected_tokens.append((corrected_token_lemma, token.idx, token.idx + len(corrected_token_lemma)))
        else:
            corrected_tokens.append((token.text, token.idx, token.idx + len(token.text)))

    return corrected_tokens


def tokenize_with_coordinates(text):
    # Tokenize the text using spaCy
    doc = nlp_es(text)

    # Extract tokens with their start and end positions
    tokens_with_coordinates = [(token.text, token.idx, token.idx + len(token.text)) for token in doc if not token.is_space]

    return tokens_with_coordinates


# Remove empty tokens   
def remove_empty_tokens(tokens):
    # Filter out tokens with empty text
    non_empty_tokens = [(token[0], token[1], token[2]) for token in tokens if token[0]]
    return non_empty_tokens


# Main function to process the text
def pre_process_text(text, remove_punctuation_call=True, spell_check_call=True):
    # Tokenize the text with coordinates
    tokens_with_coordinates = tokenize_with_coordinates(text)

    # Apply each processing step to the tokens
    if remove_punctuation_call:
        tokens_with_coordinates = remove_punctuation(tokens_with_coordinates)

    if spell_check_call:
        tokens_with_coordinates = spell_check_and_lemmatize(tokens_with_coordinates)

    # Remove empty tokens
    tokens_with_coordinates = remove_empty_tokens(tokens_with_coordinates)

    # Remove extra patient information
    tokens_with_coordinates = tokens_with_coordinates[32:]  # nº-motiu
    tokens_with_coordinates = tokens_with_coordinates[:-5]  # nhc-lopd

    # Remove accent marks from tokens
    tokens_with_coordinates = [(unidecode(token[0]), token[1], token[2]) for token in tokens_with_coordinates]

    # Return the modified tokens
    return tokens_with_coordinates

# %% [markdown]
# Real Usage

# %%
# Load the JSON file
with open("negacio_test_v2024.json", "r", encoding="utf-8") as file:
    training_data = json.load(file)

# List to store processed texts
processed_texts = []

# Iterate over each entry in the training data
for entry in training_data:
    text = entry["data"]["text"]  # Extract the text from the JSON object
    processed_text = pre_process_text(text, remove_punctuation_call=True, spell_check_call=False)
    processed_texts.append(processed_text)

# Printing (not necessary)
for processed_text in processed_texts:
    for token, start, end in processed_text:
        print(f"Token: {token}, Start: {start}, End: {end}")
# Out:
# Token: al, Start: 329, End: 331
# Token: parto, Start: 332, End: 337
# Token: por, Start: 338, End: 341
# Token: pequeno, Start: 342, End: 349
# Token: para, Start: 350, End: 354
# Token: la, Start: 355, End: 357
# Token: edad, Start: 358, End: 362
# Token: gestacional, Start: 363, End: 374
# Token: peg, Start: 377, End: 380
# Token: antecedents, Start: 383, End: 394
# Token: no, Start: 395, End: 397
# Token: alergias, Start: 398, End: 406
# Token: medicamentosas, Start: 407, End: 421
# Token: conocidas, Start: 422, End: 431
# Token: antcededentes, Start: 432, End: 445
# Token: medicoquirurgicos, Start: 446, End: 464
# Token: protesis, Start: 466, End: 474
# Token: mamaria, Start: 475, End: 482
# Token: adenoidectomia, Start: 484, End: 498
# Token: niega, Start: 499, End: 504
# Token: habitos, Start: 505, End: 512
# Token: toxicos, Start: 513, End: 520
# Token: medicacio, Start: 521, End: 530
# Token: habitual, Start: 531, End: 539
# Token: anafranil25, Start: 540, End: 551
# Token: mg, Start: 552, End: 555
# Token: diario, Start: 556, End: 562
# Token: yodocefol, Start: 564, End: 573
# Token: hierro, Start: 575, End: 581
# Token: oral, Start: 582, End: 586
# Token: ranitidina, Start: 588, End: 598
# Token: 150, Start: 599, End: 602
# Token: mg, Start: 603, End: 605
# Token: proces, Start: 607, End: 613
# Token: actual, Start: 614, End: 620
# Token: edad, Start: 621, End: 625
# Token: 42, Start: 627, End: 629
# Token: anos, Start: 630, End: 634
# Token: tpal, Start: 635, End: 639
# Token: 1001, Start: 641, End: 645
# Token: eutocico, Start: 647, End: 655
# Token: fur, Start: 657, End: 660
# Token: 21122019, Start: 662, End: 672
# Token: sg, Start: 673, End: 675
# Token: 40, Start: 677, End: 679
# Token: 0, Start: 680, End: 681
# Token: gsrh, Start: 682, End: 686
# Token: a, Start: 687, End: 689
# Token: gestacion, Start: 690, End: 699
# Token: controlada, Start: 700, End: 710
# Token: en, Start: 711, End: 713
# Token: alto, Start: 714, End: 718
# Token: riesgo, Start: 719, End: 725
# Token: obstetrico, Start: 726, End: 736
# Token: aro, Start: 738, End: 741
# Token: por, Start: 743, End: 746
# Token: antecedente, Start: 747, End: 758
# Token: de, Start: 759, End: 761
# Token: depresion, Start: 762, End: 771
# Token: postparto, Start: 772, End: 781
# Token: diabetes, Start: 784, End: 792
# Token: gestacional, Start: 793, End: 804
# Token: dga1, Start: 807, End: 811
# Token: pequeno, Start: 816, End: 823
# Token: para, Start: 824, End: 828
# Token: la, Start: 829, End: 831
# Token: edad, Start: 832, End: 836
# Token: gestacional, Start: 837, End: 848
# Token: peg, Start: 850, End: 853
# Token: secundigesta, Start: 855, End: 867
# Token: de, Start: 868, End: 870
# Token: 40, Start: 871, End: 873
# Token: semanas, Start: 874, End: 881
# Token: que, Start: 882, End: 885
# Token: ingresa, Start: 886, End: 893
# Token: para, Start: 894, End: 898
# Token: induccion, Start: 899, End: 908
# Token: por, Start: 909, End: 912
# Token: feto, Start: 913, End: 917
# Token: pequeno, Start: 918, End: 925
# Token: para, Start: 926, End: 930
# Token: la, Start: 931, End: 933
# Token: edad, Start: 934, End: 938
# Token: gestacional, Start: 939, End: 950
# Token: peg, Start: 952, End: 955
# Token: resumen, Start: 958, End: 965
# Token: gestacional, Start: 966, End: 977
# Token: as, Start: 980, End: 982
# Token: 1, Start: 983, End: 984
# Token: t, Start: 985, End: 986
# Token: hb121, Start: 988, End: 995
# Token: hto342, Start: 996, End: 1004
# Token: as, Start: 1007, End: 1009
# Token: 2, Start: 1010, End: 1011
# Token: t, Start: 1011, End: 1012
# Token: hb, Start: 1014, End: 1016
# Token: 106, Start: 1017, End: 1021
# Token: hto, Start: 1023, End: 1026
# Token: 319, Start: 1027, End: 1032
# Token: as, Start: 1035, End: 1037
# Token: 3, Start: 1038, End: 1039
# Token: t, Start: 1039, End: 1040
# Token: hb, Start: 1042, End: 1044
# Token: 129, Start: 1045, End: 1049
# Token: hto, Start: 1050, End: 1053
# Token: 397, Start: 1054, End: 1059
# Token: pq, Start: 1060, End: 1062
# Token: 245, Start: 1063, End: 1066
# Token: coagulacion, Start: 1068, End: 1079
# Token: normal, Start: 1080, End: 1086
# Token: bioquimica, Start: 1088, End: 1098
# Token: normal, Start: 1099, End: 1105
# Token: vih, Start: 1107, End: 1110
# Token: negativo, Start: 1111, End: 1119
# Token: serologias, Start: 1121, End: 1131
# Token: rubeola, Start: 1133, End: 1140
# Token: no, Start: 1141, End: 1143
# Token: inmune, Start: 1144, End: 1150
# Token: toxoplasma, Start: 1152, End: 1162
# Token: no, Start: 1163, End: 1165
# Token: immune, Start: 1166, End: 1172
# Token: lues, Start: 1174, End: 1178
# Token: vih, Start: 1179, End: 1182
# Token: vhb, Start: 1184, End: 1187
# Token: y, Start: 1188, End: 1189
# Token: vhc, Start: 1190, End: 1193
# Token: negativos, Start: 1194, End: 1203
# Token: triple, Start: 1207, End: 1213
# Token: screening, Start: 1214, End: 1223
# Token: 114045, Start: 1225, End: 1232
# Token: down, Start: 1233, End: 1237
# Token: i, Start: 1238, End: 1239
# Token: 160540, Start: 1240, End: 1247
# Token: edwards, Start: 1248, End: 1255
# Token: riesgo, Start: 1258, End: 1264
# Token: de, Start: 1265, End: 1267
# Token: pe, Start: 1268, End: 1270
# Token: bajo, Start: 1272, End: 1276
# Token: riesgo, Start: 1277, End: 1283
# Token: osullivan, Start: 1286, End: 1296
# Token: 216mg, Start: 1298, End: 1303
# Token: dl, Start: 1304, End: 1306
# Token: sgb, Start: 1309, End: 1312
# Token: negativo, Start: 1313, End: 1321
# Token: eco, Start: 1324, End: 1327
# Token: 1o, Start: 1328, End: 1330
# Token: t, Start: 1331, End: 1332
# Token: crl60, Start: 1334, End: 1340
# Token: tn17, Start: 1341, End: 1347
# Token: 2o, Start: 1350, End: 1352
# Token: t, Start: 1353, End: 1354
# Token: morfologia, Start: 1356, End: 1366
# Token: normal, Start: 1367, End: 1373
# Token: uterinas, Start: 1375, End: 1383
# Token: lc, Start: 1385, End: 1387
# Token: eco, Start: 1390, End: 1393
# Token: 39, Start: 1394, End: 1396
# Token: 3sg, Start: 1397, End: 1400
# Token: cefalica, Start: 1402, End: 1410
# Token: pfe, Start: 1412, End: 1415
# Token: 2816, Start: 1416, End: 1420
# Token: g, Start: 1421, End: 1422
# Token: p9, Start: 1424, End: 1426
# Token: dopplers, Start: 1429, End: 1437
# Token: normales, Start: 1438, End: 1446
# Token: peg, Start: 1448, End: 1451
# Token: nhc, Start: 1453, End: 1456
# Token: nbsp, Start: 1469, End: 1473
# Token: nbspamivobs, Start: 1486, End: 1500
# Token: 13, Start: 1501, End: 1504
# Token: lopd, Start: 1505, End: 1509
# Token: evolucio, Start: 1510, End: 1518
# Token: clinica, Start: 1519, End: 1526
# Token: ingresa, Start: 1527, End: 1534
# Token: secundigesta, Start: 1535, End: 1547
# Token: para, Start: 1548, End: 1552
# Token: induccion, Start: 1553, End: 1562
# Token: al, Start: 1563, End: 1565
# Token: parot, Start: 1566, End: 1571
# Token: por, Start: 1572, End: 1575
# Token: feto, Start: 1576, End: 1580
# Token: pequeno, Start: 1581, End: 1588
# Token: para, Start: 1589, End: 1593
# Token: la, Start: 1594, End: 1596
# Token: edad, Start: 1597, End: 1601
# Token: gestacional, Start: 1602, End: 1613
# Token: peg, Start: 1615, End: 1618
# Token: se, Start: 1621, End: 1623
# Token: inicia, Start: 1624, End: 1630
# Token: maduracion, Start: 1631, End: 1641
# Token: cervical, Start: 1642, End: 1650
# Token: con, Start: 1651, End: 1654
# Token: dinoprostona, Start: 1655, End: 1667
# Token: se, Start: 1670, End: 1672
# Token: administra, Start: 1673, End: 1683
# Token: analgesia, Start: 1684, End: 1693
# Token: peridural, Start: 1694, End: 1703
# Token: amniorrexis, Start: 1706, End: 1717
# Token: artificial, Start: 1718, End: 1728
# Token: evoluciona, Start: 1731, End: 1741
# Token: tacto, Start: 1742, End: 1747
# Token: hasta, Start: 1748, End: 1753
# Token: 8, Start: 1754, End: 1755
# Token: cm, Start: 1756, End: 1758
# Token: de, Start: 1759, End: 1761
# Token: dilatacion, Start: 1762, End: 1772
# Token: permaneciendo, Start: 1773, End: 1786
# Token: en, Start: 1787, End: 1789
# Token: tacto, Start: 1790, End: 1795
# Token: analogo, Start: 1796, End: 1803
# Token: durante, Start: 1804, End: 1811
# Token: 4h, Start: 1812, End: 1814
# Token: dado, Start: 1816, End: 1820
# Token: este, Start: 1821, End: 1825
# Token: motivo, Start: 1826, End: 1832
# Token: se, Start: 1833, End: 1835
# Token: cataloga, Start: 1836, End: 1844
# Token: de, Start: 1845, End: 1847
# Token: parto, Start: 1848, End: 1853
# Token: estacionado, Start: 1854, End: 1865
# Token: y, Start: 1866, End: 1867
# Token: se, Start: 1868, End: 1870
# Token: indica, Start: 1871, End: 1877
# Token: cesarea, Start: 1878, End: 1885
# Token: el, Start: 1888, End: 1890
# Token: dia, Start: 1891, End: 1894
# Token: 2892019, Start: 1895, End: 1904
# Token: se, Start: 1905, End: 1907
# Token: realiza, Start: 1908, End: 1915
# Token: cesarea, Start: 1916, End: 1923
# Token: tipo, Start: 1924, End: 1928
# Token: cohen, Start: 1929, End: 1934
# Token: se, Start: 1936, End: 1938
# Token: obtiene, Start: 1939, End: 1946
# Token: a, Start: 1947, End: 1948
# Token: las, Start: 1949, End: 1952
# Token: 807h, Start: 1953, End: 1958
# Token: recien, Start: 1959, End: 1965
# Token: nacido, Start: 1966, End: 1972
# Token: vivo, Start: 1973, End: 1977
# Token: sexo, Start: 1978, End: 1982
# Token: masculino, Start: 1983, End: 1992
# Token: apgar, Start: 1994, End: 1999
# Token: 910, Start: 2000, End: 2004
# Token: ph, Start: 2005, End: 2007
# Token: 726734, Start: 2009, End: 2018
# Token: peso, Start: 2019, End: 2023
# Token: 2930, Start: 2024, End: 2028
# Token: g, Start: 2028, End: 2030
# Token: alumbramiento, Start: 2031, End: 2044
# Token: manual, Start: 2045, End: 2051
# Token: ligadura, Start: 2053, End: 2061
# Token: tubarica, Start: 2062, End: 2070
# Token: bilateral, Start: 2071, End: 2080
# Token: hemostasia, Start: 2082, End: 2092
# Token: correcta, Start: 2093, End: 2101
# Token: procedimiento, Start: 2104, End: 2117
# Token: sin, Start: 2118, End: 2121
# Token: incidencias, Start: 2122, End: 2133
# Token: intradermica, Start: 2135, End: 2147
# Token: en, Start: 2148, End: 2150
# Token: piel, Start: 2151, End: 2155
# Token: el, Start: 2157, End: 2159
# Token: puerperio, Start: 2160, End: 2169
# Token: clinico, Start: 2170, End: 2177
# Token: transcurre, Start: 2178, End: 2188
# Token: con, Start: 2189, End: 2192
# Token: normalidad, Start: 2193, End: 2203
# Token: la, Start: 2205, End: 2207
# Token: paciente, Start: 2208, End: 2216
# Token: permanece, Start: 2217, End: 2226
# Token: con, Start: 2227, End: 2230
# Token: buen, Start: 2231, End: 2235
# Token: estado, Start: 2236, End: 2242
# Token: general, Start: 2243, End: 2250
# Token: buen, Start: 2252, End: 2256
# Token: control, Start: 2257, End: 2264
# Token: del, Start: 2265, End: 2268
# Token: dolor, Start: 2269, End: 2274
# Token: normotensa, Start: 2276, End: 2286
# Token: y, Start: 2287, End: 2288
# Token: apiretica, Start: 2289, End: 2298
# Token: utero, Start: 2300, End: 2305
# Token: tonico, Start: 2306, End: 2312
# Token: con, Start: 2313, End: 2316
# Token: perdidas, Start: 2317, End: 2325
# Token: vaginales, Start: 2326, End: 2335
# Token: escasas, Start: 2336, End: 2343
# Token: herida, Start: 2345, End: 2351
# Token: quirurgica, Start: 2352, End: 2362
# Token: con, Start: 2363, End: 2366
# Token: cicatrizacion, Start: 2367, End: 2380
# Token: correcta, Start: 2381, End: 2389
# Token: esta, Start: 2391, End: 2395
# Token: realizando, Start: 2396, End: 2406
# Token: lactancia, Start: 2407, End: 2416
# Token: materna, Start: 2417, End: 2424
# Token: durante, Start: 2426, End: 2433
# Token: su, Start: 2434, End: 2436
# Token: estancia, Start: 2437, End: 2445
# Token: en, Start: 2446, End: 2448
# Token: planta, Start: 2449, End: 2455
# Token: es, Start: 2456, End: 2458
# Token: valorada, Start: 2459, End: 2467
# Token: clinicamente, Start: 2468, End: 2480
# Token: por, Start: 2481, End: 2484
# Token: psiquiatria, Start: 2485, End: 2496
# Token: perinatal, Start: 2497, End: 2506
# Token: quienes, Start: 2507, End: 2514
# Token: reajustan, Start: 2515, End: 2524
# Token: tratamiento, Start: 2525, End: 2536
# Token: y, Start: 2537, End: 2538
# Token: solicita, Start: 2539, End: 2547
# Token: visita, Start: 2548, End: 2554
# Token: de, Start: 2555, End: 2557
# Token: control, Start: 2558, End: 2565
# Token: en, Start: 2566, End: 2568
# Token: sus, Start: 2569, End: 2572
# Token: consultas, Start: 2573, End: 2582
# Token: de, Start: 2583, End: 2585
# Token: externas, Start: 2586, End: 2594
# Token: a, Start: 2596, End: 2597
# Token: su, Start: 2598, End: 2600
# Token: vez, Start: 2601, End: 2604
# Token: es, Start: 2605, End: 2607
# Token: vacunada, Start: 2608, End: 2616
# Token: de, Start: 2617, End: 2619
# Token: triple, Start: 2620, End: 2626
# Token: virica, Start: 2627, End: 2633
# Token: por, Start: 2634, End: 2637
# Token: medicina, Start: 2638, End: 2646
# Token: preventiva, Start: 2647, End: 2657
# Token: debido, Start: 2659, End: 2665
# Token: a, Start: 2666, End: 2667
# Token: la, Start: 2668, End: 2670
# Token: buena, Start: 2671, End: 2676
# Token: evolucion, Start: 2677, End: 2686
# Token: clinica, Start: 2687, End: 2694
# Token: se, Start: 2696, End: 2698
# Token: decide, Start: 2699, End: 2705
# Token: alta, Start: 2706, End: 2710
# Token: hospitalaria, Start: 2711, End: 2723
# Token: orientacio, Start: 2725, End: 2735
# Token: diagnostica, Start: 2736, End: 2747
# Token: feto, Start: 2748, End: 2752
# Token: pequeno, Start: 2753, End: 2760
# Token: para, Start: 2761, End: 2765
# Token: la, Start: 2766, End: 2768
# Token: edad, Start: 2769, End: 2773
# Token: gestacional, Start: 2774, End: 2785
# Token: peg, Start: 2787, End: 2790
# Token: induccion, Start: 2792, End: 2801
# Token: del, Start: 2802, End: 2805
# Token: parto, Start: 2806, End: 2811
# Token: trabajo, Start: 2812, End: 2819
# Token: de, Start: 2820, End: 2822
# Token: parto, Start: 2823, End: 2828
# Token: parto, Start: 2829, End: 2834
# Token: estacionado, Start: 2835, End: 2846
# Token: cesarea, Start: 2847, End: 2854
# Token: lactancia, Start: 2855, End: 2864
# Token: materna, Start: 2865, End: 2872
# Token: puerperio, Start: 2873, End: 2882
# Token: clinico, Start: 2883, End: 2890
# Token: normal, Start: 2891, End: 2897
# Token: z3801, Start: 2898, End: 2904
# Token: nado, Start: 2905, End: 2909
# Token: unic, Start: 2910, End: 2914
# Token: nascut, Start: 2915, End: 2921
# Token: viu, Start: 2922, End: 2925
# Token: part, Start: 2927, End: 2931
# Token: per, Start: 2932, End: 2935
# Token: cesaria, Start: 2936, End: 2943
# Token: procediments, Start: 2944, End: 2956
# Token: venoclisis, Start: 2957, End: 2967
# Token: y, Start: 2968, End: 2969
# Token: sueroterapia, Start: 2970, End: 2982
# Token: monitorizacion, Start: 2983, End: 2997
# Token: fetal, Start: 2998, End: 3003
# Token: anestesia, Start: 3004, End: 3013
# Token: raquidea, Start: 3014, End: 3022
# Token: cesarea, Start: 3023, End: 3030
# Token: sutura, Start: 3032, End: 3038
# Token: intradermica, Start: 3039, End: 3051
# Token: profilaxis, Start: 3052, End: 3062
# Token: antibiotica, Start: 3063, End: 3074
# Token: profilaxis, Start: 3075, End: 3085
# Token: antitrombotica, Start: 3086, End: 3100
# Token: analgesicos, Start: 3101, End: 3112
# Token: ferroterapia, Start: 3113, End: 3125
# Token: curas, Start: 3126, End: 3131
# Token: de, Start: 3132, End: 3134
# Token: enfermeria, Start: 3135, End: 3145
# Token: tractament, Start: 3146, End: 3156
# Token: i, Start: 3157, End: 3158
# Token: recomanacions, Start: 3159, End: 3172
# Token: a, Start: 3173, End: 3174
# Token: lalta, Start: 3175, End: 3181
# Token: hierro, Start: 3182, End: 3188
# Token: 1, Start: 3189, End: 3190
# Token: comprimido, Start: 3191, End: 3201
# Token: al, Start: 3202, End: 3204
# Token: dia, Start: 3205, End: 3208
# Token: en, Start: 3209, End: 3211
# Token: ayunas, Start: 3212, End: 3218
# Token: durante, Start: 3219, End: 3226
# Token: 2, Start: 3227, End: 3228
# Token: meses, Start: 3229, End: 3234
# Token: con, Start: 3236, End: 3239
# Token: zumo, Start: 3240, End: 3244
# Token: de, Start: 3245, End: 3247
# Token: naranja, Start: 3248, End: 3255
# Token: se, Start: 3256, End: 3258
# Token: absorbe, Start: 3259, End: 3266
# Token: mejor, Start: 3267, End: 3272
# Token: nhc, Start: 3275, End: 3278
# Token: nbsp, Start: 3291, End: 3295
# Token: nbspamivobs, Start: 3308, End: 3322
# Token: 23, Start: 3323, End: 3326
# Token: lopd, Start: 3327, End: 3331
# Token: clexane, Start: 3332, End: 3339
# Token: 40, Start: 3340, End: 3342
# Token: mg, Start: 3343, End: 3345
# Token: cada, Start: 3346, End: 3350
# Token: 24, Start: 3351, End: 3353
# Token: horas, Start: 3354, End: 3359
# Token: subcutaneo, Start: 3360, End: 3370
# Token: durante, Start: 3371, End: 3378
# Token: 10, Start: 3379, End: 3381
# Token: dias, Start: 3382, End: 3386
# Token: desde, Start: 3387, End: 3392
# Token: la, Start: 3393, End: 3395
# Token: cesarea, Start: 3396, End: 3403
# Token: paracetamol, Start: 3405, End: 3416
# Token: 1gr, Start: 3417, End: 3420
# Token: cada, Start: 3421, End: 3425
# Token: 8, Start: 3426, End: 3427
# Token: horas, Start: 3428, End: 3433
# Token: si, Start: 3434, End: 3436
# Token: precisa, Start: 3437, End: 3444
# Token: para, Start: 3445, End: 3449
# Token: el, Start: 3450, End: 3452
# Token: dolor, Start: 3453, End: 3458
# Token: puede, Start: 3460, End: 3465
# Token: alternarse, Start: 3466, End: 3476
# Token: cada, Start: 3477, End: 3481
# Token: 4, Start: 3482, End: 3483
# Token: horas, Start: 3484, End: 3489
# Token: con, Start: 3490, End: 3493
# Token: 1, Start: 3494, End: 3495
# Token: comprimido, Start: 3496, End: 3506
# Token: de, Start: 3507, End: 3509
# Token: ibuprofeno, Start: 3510, End: 3520
# Token: 600, Start: 3521, End: 3524
# Token: mg, Start: 3524, End: 3526
# Token: si, Start: 3527, End: 3529
# Token: dolor, Start: 3530, End: 3535
# Token: acido, Start: 3538, End: 3543
# Token: folico, Start: 3544, End: 3550
# Token: 1, Start: 3551, End: 3552
# Token: al, Start: 3553, End: 3555
# Token: dia, Start: 3556, End: 3559
# Token: durante, Start: 3560, End: 3567
# Token: la, Start: 3568, End: 3570
# Token: lactancia, Start: 3571, End: 3580
# Token: control, Start: 3581, End: 3588
# Token: control, Start: 3589, End: 3596
# Token: por, Start: 3597, End: 3600
# Token: su, Start: 3601, End: 3603
# Token: matrona, Start: 3604, End: 3611
# Token: de, Start: 3612, End: 3614
# Token: zona, Start: 3615, End: 3619
# Token: en, Start: 3620, End: 3622
# Token: 710, Start: 3623, End: 3627
# Token: dias, Start: 3628, End: 3632
# Token: se, Start: 3634, End: 3636
# Token: recomienda, Start: 3637, End: 3647
# Token: esperar, Start: 3648, End: 3655
# Token: minimo, Start: 3656, End: 3662
# Token: un, Start: 3663, End: 3665
# Token: ano, Start: 3666, End: 3669
# Token: para, Start: 3670, End: 3674
# Token: buscar, Start: 3675, End: 3681
# Token: nuevo, Start: 3682, End: 3687
# Token: embarazo, Start: 3688, End: 3696
# Token: se, Start: 3698, End: 3700
# Token: recomienda, Start: 3701, End: 3711
# Token: abundante, Start: 3712, End: 3721
# Token: ingesta, Start: 3722, End: 3729
# Token: de, Start: 3730, End: 3732
# Token: liquidos, Start: 3733, End: 3741
# Token: y, Start: 3742, End: 3743
# Token: dieta, Start: 3744, End: 3749
# Token: variada, Start: 3750, End: 3757
# Token: y, Start: 3758, End: 3759
# Token: equilibrada, Start: 3760, End: 3771
# Token: lavado, Start: 3773, End: 3779
# Token: diario, Start: 3780, End: 3786
# Token: de, Start: 3787, End: 3789
# Token: herida, Start: 3790, End: 3796
# Token: quirurgica, Start: 3797, End: 3807
# Token: con, Start: 3808, End: 3811
# Token: agua, Start: 3812, End: 3816
# Token: y, Start: 3817, End: 3818
# Token: jabon, Start: 3819, End: 3824
# Token: neutro, Start: 3825, End: 3831
# Token: y, Start: 3832, End: 3833
# Token: realizacion, Start: 3834, End: 3845
# Token: progresiva, Start: 3846, End: 3856
# Token: de, Start: 3857, End: 3859
# Token: actividad, Start: 3860, End: 3869
# Token: fisica, Start: 3870, End: 3876
# Token: asi, Start: 3878, End: 3881
# Token: como, Start: 3882, End: 3886
# Token: evitar, Start: 3887, End: 3893
# Token: inmersion, Start: 3894, End: 3903
# Token: en, Start: 3904, End: 3906
# Token: banera, Start: 3907, End: 3913
# Token: o, Start: 3914, End: 3915
# Token: piscina, Start: 3916, End: 3923
# Token: hasta, Start: 3924, End: 3929
# Token: finalizar, Start: 3930, End: 3939
# Token: el, Start: 3940, End: 3942
# Token: puerperio, Start: 3943, End: 3952
# Token: se, Start: 3954, End: 3956
# Token: informa, Start: 3957, End: 3964
# Token: de, Start: 3965, End: 3967
# Token: signos, Start: 3968, End: 3974
# Token: y, Start: 3975, End: 3976
# Token: sintomas, Start: 3977, End: 3985
# Token: de, Start: 3986, End: 3988
# Token: alarma, Start: 3989, End: 3995
# Token: fiebre, Start: 3997, End: 4003
# Token: termometrada, Start: 4004, End: 4016
# Token: en, Start: 4017, End: 4019
# Token: domicilio, Start: 4020, End: 4029
# Token: eritema, Start: 4031, End: 4038
# Token: mamario, Start: 4039, End: 4046
# Token: secrecion, Start: 4048, End: 4057
# Token: purulenta, Start: 4058, End: 4067
# Token: por, Start: 4068, End: 4071
# Token: herida, Start: 4072, End: 4078
# Token: quirurgica, Start: 4079, End: 4089
# Token: o, Start: 4090, End: 4091
# Token: secrecion, Start: 4092, End: 4101
# Token: vaginal, Start: 4102, End: 4109
# Token: maloliente, Start: 4110, End: 4120
# Token: por, Start: 4122, End: 4125
# Token: los, Start: 4126, End: 4129
# Token: que, Start: 4130, End: 4133
# Token: debe, Start: 4134, End: 4138
# Token: volver, Start: 4139, End: 4145
# Token: a, Start: 4146, End: 4147
# Token: consultar, Start: 4148, End: 4157
# Token: por, Start: 4158, End: 4161
# Token: urgencias, Start: 4162, End: 4171
# Token: acudir, Start: 4173, End: 4179
# Token: a, Start: 4180, End: 4181
# Token: visita, Start: 4182, End: 4188
# Token: de, Start: 4189, End: 4191
# Token: control, Start: 4192, End: 4199
# Token: en, Start: 4200, End: 4202
# Token: consultas, Start: 4203, End: 4212
# Token: externas, Start: 4213, End: 4221
# Token: de, Start: 4222, End: 4224
# Token: psiquiatria, Start: 4225, End: 4236
# Token: segun, Start: 4237, End: 4242
# Token: citacion, Start: 4243, End: 4251
# Token: 051119, Start: 4253, End: 4261
# Token: destinacio, Start: 4263, End: 4273
# Token: a, Start: 4274, End: 4275
# Token: lalta, Start: 4276, End: 4282
# Token: a, Start: 4284, End: 4285
# Token: domicili, Start: 4286, End: 4294
# Token: dalta, Start: 280, End: 286
# Token: dhospitalitzacio, Start: 287, End: 304
# Token: motiu, Start: 305, End: 310
# Token: dingres, Start: 311, End: 319
# Token: varon, Start: 320, End: 325
# Token: 22, Start: 326, End: 328
# Token: anos, Start: 329, End: 333
# Token: que, Start: 334, End: 337
# Token: acude, Start: 338, End: 343
# Token: por, Start: 344, End: 347
# Token: fiebre, Start: 348, End: 354
# Token: antecedents, Start: 356, End: 367
# Token: alergias, Start: 368, End: 376
# Token: no, Start: 377, End: 379
# Token: refiere, Start: 380, End: 387
# Token: alergias, Start: 388, End: 396
# Token: medicamentosas, Start: 397, End: 411
# Token: conocidas, Start: 412, End: 421
# Token: antecedenes, Start: 423, End: 434
# Token: personales, Start: 435, End: 445
# Token: niega, Start: 446, End: 451
# Token: habitos, Start: 452, End: 459
# Token: toxicos, Start: 460, End: 467
# Token: antecedentes, Start: 469, End: 481
# Token: medicos, Start: 482, End: 489
# Token: infeccion, Start: 493, End: 502
# Token: por, Start: 503, End: 506
# Token: vih, Start: 507, End: 510
# Token: diagnosticada, Start: 511, End: 524
# Token: en, Start: 525, End: 527
# Token: octubre2015, Start: 528, End: 540
# Token: control, Start: 542, End: 549
# Token: por, Start: 550, End: 553
# Token: dr, Start: 554, End: 556
# Token: en, Start: 574, End: 576
# Token: tar, Start: 577, End: 580
# Token: con, Start: 581, End: 584
# Token: triumeq, Start: 585, End: 592
# Token: desde, Start: 593, End: 598
# Token: octubre, Start: 599, End: 606
# Token: 2015, Start: 607, End: 611
# Token: con, Start: 612, End: 615
# Token: buen, Start: 616, End: 620
# Token: cumplimiento, Start: 621, End: 633
# Token: terapeutico, Start: 634, End: 645
# Token: en, Start: 647, End: 649
# Token: seguimiento, Start: 650, End: 661
# Token: en, Start: 662, End: 664
# Token: cex, Start: 665, End: 668
# Token: infecciosas, Start: 669, End: 680
# Token: dr, Start: 682, End: 684
# Token: ultima, Start: 698, End: 704
# Token: analitica, Start: 705, End: 714
# Token: nov, Start: 716, End: 719
# Token: 17, Start: 720, End: 722
# Token: cv, Start: 724, End: 726
# Token: lt50, Start: 728, End: 733
# Token: cd4, Start: 735, End: 738
# Token: 1300, Start: 739, End: 743
# Token: serologies, Start: 747, End: 757
# Token: hbsag, Start: 759, End: 764
# Token: negatiu, Start: 765, End: 772
# Token: hbsac, Start: 774, End: 779
# Token: positiu, Start: 780, End: 787
# Token: hbcac, Start: 789, End: 794
# Token: negatiu, Start: 795, End: 802
# Token: vhc, Start: 804, End: 807
# Token: negativa, Start: 808, End: 816
# Token: antecedentes, Start: 817, End: 830
# Token: its, Start: 831, End: 834
# Token: uretritis, Start: 838, End: 847
# Token: gonococica, Start: 848, End: 858
# Token: en, Start: 859, End: 861
# Token: mayo, Start: 862, End: 866
# Token: 2017, Start: 867, End: 871
# Token: realizo, Start: 873, End: 880
# Token: tratamientio, Start: 881, End: 893
# Token: lues, Start: 897, End: 901
# Token: latente, Start: 902, End: 909
# Token: en, Start: 910, End: 912
# Token: sept, Start: 913, End: 917
# Token: 2017, Start: 918, End: 922
# Token: tratada, Start: 923, End: 930
# Token: con, Start: 931, End: 934
# Token: 3, Start: 935, End: 936
# Token: dosis, Start: 937, End: 942
# Token: de, Start: 943, End: 945
# Token: penicilina, Start: 946, End: 956
# Token: im, Start: 957, End: 959
# Token: hsil, Start: 961, End: 966
# Token: anal, Start: 967, End: 971
# Token: displasia, Start: 973, End: 982
# Token: moderadaain2, Start: 983, End: 996
# Token: vph, Start: 999, End: 1002
# Token: 18425881, Start: 1003, End: 1014
# Token: en, Start: 1016, End: 1018
# Token: curso, Start: 1019, End: 1024
# Token: de, Start: 1025, End: 1027
# Token: vacunacion, Start: 1028, End: 1038
# Token: de, Start: 1039, End: 1041
# Token: vph, Start: 1042, End: 1045
# Token: ha, Start: 1047, End: 1049
# Token: recibido, Start: 1050, End: 1058
# Token: 2, Start: 1059, End: 1060
# Token: dosis, Start: 1061, End: 1066
# Token: citologia, Start: 1071, End: 1080
# Token: nov, Start: 1082, End: 1085
# Token: 17, Start: 1086, End: 1088
# Token: mucosa, Start: 1091, End: 1097
# Token: y, Start: 1098, End: 1099
# Token: zona, Start: 1100, End: 1104
# Token: de, Start: 1105, End: 1107
# Token: transicion, Start: 1108, End: 1118
# Token: canal, Start: 1119, End: 1124
# Token: anal, Start: 1125, End: 1129
# Token: con, Start: 1130, End: 1133
# Token: signos, Start: 1134, End: 1140
# Token: de, Start: 1141, End: 1143
# Token: coilocitosis, Start: 1144, End: 1156
# Token: y, Start: 1157, End: 1158
# Token: neoplasia, Start: 1159, End: 1168
# Token: escamosa, Start: 1169, End: 1177
# Token: intraepitelial, Start: 1178, End: 1192
# Token: anal, Start: 1193, End: 1197
# Token: de, Start: 1198, End: 1200
# Token: algo, Start: 1201, End: 1205
# Token: grado, Start: 1206, End: 1211
# Token: hgasin, Start: 1212, End: 1219
# Token: amigdalitis, Start: 1221, End: 1233
# Token: de, Start: 1234, End: 1236
# Token: repeticion, Start: 1237, End: 1247
# Token: por, Start: 1248, End: 1251
# Token: la, Start: 1252, End: 1254
# Token: que, Start: 1255, End: 1258
# Token: se, Start: 1259, End: 1261
# Token: autoadministra, Start: 1262, End: 1276
# Token: amoxicilina, Start: 1277, End: 1288
# Token: ultimos, Start: 1290, End: 1297
# Token: dos, Start: 1298, End: 1301
# Token: anos, Start: 1302, End: 1306
# Token: sin, Start: 1307, End: 1310
# Token: episodios, Start: 1311, End: 1320
# Token: antecedentes, Start: 1322, End: 1334
# Token: quirurgicos, Start: 1335, End: 1346
# Token: no, Start: 1348, End: 1350
# Token: refiere, Start: 1351, End: 1358
# Token: situacion, Start: 1360, End: 1369
# Token: sociofuncional, Start: 1370, End: 1384
# Token: independiente, Start: 1386, End: 1399
# Token: para, Start: 1400, End: 1404
# Token: las, Start: 1405, End: 1408
# Token: activdades, Start: 1409, End: 1419
# Token: basicas, Start: 1420, End: 1427
# Token: e, Start: 1428, End: 1429
# Token: instrumentales, Start: 1430, End: 1444
# Token: de, Start: 1445, End: 1447
# Token: la, Start: 1448, End: 1450
# Token: vida, Start: 1451, End: 1455
# Token: diaria, Start: 1456, End: 1462
# Token: tiene, Start: 1464, End: 1469
# Token: pareja, Start: 1470, End: 1476
# Token: estable, Start: 1477, End: 1484
# Token: vive, Start: 1486, End: 1490
# Token: con, Start: 1491, End: 1494
# Token: su, Start: 1495, End: 1497
# Token: tia, Start: 1498, End: 1501
# Token: trabaja, Start: 1503, End: 1510
# Token: como, Start: 1511, End: 1515
# Token: barista, Start: 1516, End: 1523
# Token: medicacio, Start: 1525, End: 1534
# Token: habitual, Start: 1535, End: 1543
# Token: triumeq, Start: 1544, End: 1551
# Token: abacavir, Start: 1553, End: 1561
# Token: dolutegravir, Start: 1564, End: 1576
# Token: lamivudina, Start: 1579, End: 1589
# Token: proces, Start: 1591, End: 1597
# Token: actual, Start: 1598, End: 1604
# Token: refiere, Start: 1605, End: 1612
# Token: que, Start: 1613, End: 1616
# Token: estando, Start: 1617, End: 1624
# Token: de, Start: 1625, End: 1627
# Token: viaje, Start: 1628, End: 1633
# Token: la, Start: 1635, End: 1637
# Token: noche, Start: 1638, End: 1643
# Token: del, Start: 1644, End: 1647
# Token: martes, Start: 1648, End: 1654
# Token: 27, Start: 1655, End: 1657
# Token: de, Start: 1658, End: 1660
# Token: febrero, Start: 1661, End: 1668
# Token: comienza, Start: 1669, End: 1677
# Token: con, Start: 1678, End: 1681
# Token: un, Start: 1682, End: 1684
# Token: cuadro, Start: 1685, End: 1691
# Token: de, Start: 1692, End: 1694
# Token: malestar, Start: 1695, End: 1703
# Token: general, Start: 1704, End: 1711
# Token: odinofagia, Start: 1713, End: 1723
# Token: cefalea, Start: 1725, End: 1732
# Token: holocraneal, Start: 1733, End: 1744
# Token: intensa, Start: 1746, End: 1753
# Token: que, Start: 1754, End: 1757
# Token: le, Start: 1758, End: 1760
# Token: despierta, Start: 1761, End: 1770
# Token: por, Start: 1771, End: 1774
# Token: la, Start: 1775, End: 1777
# Token: noche, Start: 1778, End: 1783
# Token: sin, Start: 1784, End: 1787
# Token: haber, Start: 1788, End: 1793
# Token: tomado, Start: 1794, End: 1800
# Token: analgesia, Start: 1801, End: 1810
# Token: para, Start: 1811, End: 1815
# Token: esto, Start: 1816, End: 1820
# Token: el, Start: 1822, End: 1824
# Token: cuadro, Start: 1825, End: 1831
# Token: se, Start: 1832, End: 1834
# Token: acompana, Start: 1835, End: 1843
# Token: de, Start: 1844, End: 1846
# Token: sensacion, Start: 1847, End: 1856
# Token: distermica, Start: 1857, End: 1867
# Token: con, Start: 1869, End: 1872
# Token: escalofrios, Start: 1873, End: 1884
# Token: sin, Start: 1886, End: 1889
# Token: haber, Start: 1890, End: 1895
# Token: termometrado, Start: 1896, End: 1908
# Token: fiebre, Start: 1909, End: 1915
# Token: ademas, Start: 1917, End: 1923
# Token: refiere, Start: 1924, End: 1931
# Token: dolor, Start: 1932, End: 1937
# Token: en, Start: 1938, End: 1940
# Token: region, Start: 1941, End: 1947
# Token: lumbosacra, Start: 1948, End: 1958
# Token: sin, Start: 1960, End: 1963
# Token: haber, Start: 1964, End: 1969
# Token: presentado, Start: 1970, End: 1980
# Token: traumatismo, Start: 1981, End: 1992
# Token: previo, Start: 1993, End: 1999
# Token: niega, Start: 2001, End: 2006
# Token: dolor, Start: 2007, End: 2012
# Token: toracico, Start: 2013, End: 2021
# Token: disnea, Start: 2023, End: 2029
# Token: tos, Start: 2031, End: 2034
# Token: expectoracion, Start: 2036, End: 2049
# Token: dolor, Start: 2051, End: 2056
# Token: abdominal, Start: 2057, End: 2066
# Token: o, Start: 2067, End: 2068
# Token: diarrea, Start: 2069, End: 2076
# Token: refiere, Start: 2078, End: 2085
# Token: disuria, Start: 2086, End: 2093
# Token: de, Start: 2094, End: 2096
# Token: dias, Start: 2097, End: 2101
# Token: de, Start: 2102, End: 2104
# Token: evolucion, Start: 2105, End: 2114
# Token: sin, Start: 2116, End: 2119
# Token: secrecion, Start: 2120, End: 2129
# Token: uretral, Start: 2130, End: 2137
# Token: explica, Start: 2139, End: 2146
# Token: relaciones, Start: 2147, End: 2157
# Token: sexuales, Start: 2158, End: 2166
# Token: sin, Start: 2167, End: 2170
# Token: proteccion, Start: 2171, End: 2181
# Token: con, Start: 2182, End: 2185
# Token: su, Start: 2186, End: 2188
# Token: pareja, Start: 2189, End: 2195
# Token: habitual, Start: 2196, End: 2204
# Token: niega, Start: 2206, End: 2211
# Token: consumo, Start: 2212, End: 2219
# Token: de, Start: 2220, End: 2222
# Token: toxicos, Start: 2223, End: 2230
# Token: o, Start: 2231, End: 2232
# Token: metamizol, Start: 2233, End: 2242
# Token: los, Start: 2243, End: 2246
# Token: dias, Start: 2247, End: 2251
# Token: previos, Start: 2252, End: 2259
# Token: nhc, Start: 2261, End: 2264
# Token: agevinf, Start: 2287, End: 2296
# Token: 14, Start: 2297, End: 2300
# Token: lopd, Start: 2301, End: 2305
# Token: exploracio, Start: 2306, End: 2316
# Token: fisica, Start: 2317, End: 2323
# Token: exploracion, Start: 2324, End: 2335
# Token: fisica, Start: 2336, End: 2342
# Token: urgencias, Start: 2343, End: 2352
# Token: ta, Start: 2353, End: 2355
# Token: 12966mmhg, Start: 2356, End: 2366
# Token: fc, Start: 2368, End: 2370
# Token: 110lpm, Start: 2371, End: 2377
# Token: ta, Start: 2379, End: 2381
# Token: 382oc, Start: 2382, End: 2388
# Token: sato2, Start: 2390, End: 2395
# Token: 100aa, Start: 2396, End: 2402
# Token: buen, Start: 2403, End: 2407
# Token: estado, Start: 2408, End: 2414
# Token: general, Start: 2415, End: 2422
# Token: normocoloreado, Start: 2424, End: 2438
# Token: normohidratado, Start: 2440, End: 2454
# Token: y, Start: 2455, End: 2456
# Token: normoperfundido, Start: 2457, End: 2472
# Token: no, Start: 2474, End: 2476
# Token: dolor, Start: 2477, End: 2482
# Token: a, Start: 2483, End: 2484
# Token: la, Start: 2485, End: 2487
# Token: palpacion, Start: 2488, End: 2497
# Token: de, Start: 2498, End: 2500
# Token: apofisis, Start: 2501, End: 2509
# Token: espinosas, Start: 2510, End: 2519
# Token: no, Start: 2521, End: 2523
# Token: lesiones, Start: 2524, End: 2532
# Token: cutaneas, Start: 2533, End: 2541
# Token: no, Start: 2543, End: 2545
# Token: palpo, Start: 2546, End: 2551
# Token: adenopatias, Start: 2552, End: 2563
# Token: cervicales, Start: 2564, End: 2574
# Token: ni, Start: 2575, End: 2577
# Token: supraclaviculares, Start: 2578, End: 2595
# Token: acv, Start: 2597, End: 2600
# Token: tcr, Start: 2602, End: 2605
# Token: no, Start: 2607, End: 2609
# Token: ausculto, Start: 2610, End: 2618
# Token: soplos, Start: 2619, End: 2625
# Token: no, Start: 2627, End: 2629
# Token: iy, Start: 2630, End: 2632
# Token: ni, Start: 2633, End: 2635
# Token: rhy, Start: 2636, End: 2639
# Token: no, Start: 2641, End: 2643
# Token: edemas, Start: 2644, End: 2650
# Token: en, Start: 2651, End: 2653
# Token: extremidades, Start: 2654, End: 2666
# Token: inferiores, Start: 2667, End: 2677
# Token: pulsos, Start: 2679, End: 2685
# Token: perifericos, Start: 2686, End: 2697
# Token: presentes, Start: 2698, End: 2707
# Token: y, Start: 2708, End: 2709
# Token: simetricos, Start: 2710, End: 2720
# Token: ar, Start: 2722, End: 2724
# Token: eupneico, Start: 2726, End: 2734
# Token: mvc, Start: 2736, End: 2739
# Token: sin, Start: 2741, End: 2744
# Token: ruidos, Start: 2745, End: 2751
# Token: sobreanadidos, Start: 2752, End: 2765
# Token: abd, Start: 2767, End: 2770
# Token: depresible, Start: 2772, End: 2782
# Token: no, Start: 2784, End: 2786
# Token: doloroso, Start: 2787, End: 2795
# Token: a, Start: 2796, End: 2797
# Token: la, Start: 2798, End: 2800
# Token: palpacion, Start: 2801, End: 2810
# Token: no, Start: 2812, End: 2814
# Token: palpo, Start: 2815, End: 2820
# Token: masas, Start: 2821, End: 2826
# Token: ni, Start: 2827, End: 2829
# Token: megalias, Start: 2830, End: 2838
# Token: peristalsis, Start: 2840, End: 2851
# Token: conservada, Start: 2852, End: 2862
# Token: sin, Start: 2864, End: 2867
# Token: signos, Start: 2868, End: 2874
# Token: de, Start: 2875, End: 2877
# Token: irritacion, Start: 2878, End: 2888
# Token: peritoneal, Start: 2889, End: 2899
# Token: ppl, Start: 2901, End: 2904
# Token: bilateral, Start: 2905, End: 2914
# Token: no, Start: 2915, End: 2917
# Token: dolorosa, Start: 2918, End: 2926
# Token: nrl, Start: 2928, End: 2931
# Token: consciente, Start: 2933, End: 2943
# Token: y, Start: 2944, End: 2945
# Token: orientado, Start: 2946, End: 2955
# Token: en, Start: 2956, End: 2958
# Token: las, Start: 2959, End: 2962
# Token: tres, Start: 2963, End: 2967
# Token: esferas, Start: 2968, End: 2975
# Token: pupilas, Start: 2977, End: 2984
# Token: isocoricas, Start: 2985, End: 2995
# Token: y, Start: 2996, End: 2997
# Token: normorreactivas, Start: 2998, End: 3013
# Token: pares, Start: 3015, End: 3020
# Token: craneales, Start: 3021, End: 3030
# Token: conservados, Start: 3031, End: 3042
# Token: y, Start: 3043, End: 3044
# Token: simetricos, Start: 3045, End: 3055
# Token: no, Start: 3057, End: 3059
# Token: dismetrias, Start: 3060, End: 3070
# Token: no, Start: 3072, End: 3074
# Token: flapping, Start: 3075, End: 3083
# Token: no, Start: 3085, End: 3087
# Token: rigidez, Start: 3088, End: 3095
# Token: de, Start: 3096, End: 3098
# Token: nuca, Start: 3099, End: 3103
# Token: ni, Start: 3104, End: 3106
# Token: signos, Start: 3107, End: 3113
# Token: meningeos, Start: 3114, End: 3123
# Token: exploracion, Start: 3125, End: 3136
# Token: fisica, Start: 3137, End: 3143
# Token: urgencias, Start: 3144, End: 3153
# Token: ta, Start: 3154, End: 3156
# Token: 10670mmhg, Start: 3157, End: 3167
# Token: fc, Start: 3169, End: 3171
# Token: 102lpm, Start: 3172, End: 3178
# Token: toc, Start: 3180, End: 3183
# Token: 365, Start: 3184, End: 3188
# Token: sato2, Start: 3190, End: 3195
# Token: 97, Start: 3196, End: 3199
# Token: aa, Start: 3200, End: 3202
# Token: aspecto, Start: 3204, End: 3211
# Token: general, Start: 3212, End: 3219
# Token: buen, Start: 3221, End: 3225
# Token: estado, Start: 3226, End: 3232
# Token: general, Start: 3233, End: 3240
# Token: afebril, Start: 3242, End: 3249
# Token: y, Start: 3250, End: 3251
# Token: hemodinamicamente, Start: 3252, End: 3269
# Token: estable, Start: 3270, End: 3277
# Token: normohidratado, Start: 3279, End: 3293
# Token: y, Start: 3294, End: 3295
# Token: normocoloreado, Start: 3296, End: 3310
# Token: eupneico, Start: 3312, End: 3320
# Token: en, Start: 3321, End: 3323
# Token: reposo, Start: 3324, End: 3330
# Token: cabeza, Start: 3332, End: 3338
# Token: y, Start: 3339, End: 3340
# Token: cuello, Start: 3341, End: 3347
# Token: no, Start: 3349, End: 3351
# Token: se, Start: 3352, End: 3354
# Token: palpan, Start: 3355, End: 3361
# Token: adenopatias, Start: 3362, End: 3373
# Token: laterocervicales, Start: 3374, End: 3390
# Token: ni, Start: 3391, End: 3393
# Token: supraclaviculares, Start: 3394, End: 3411
# Token: faringe, Start: 3413, End: 3420
# Token: hiperemica, Start: 3421, End: 3431
# Token: amigdalas, Start: 3433, End: 3442
# Token: hipetroficas, Start: 3443, End: 3455
# Token: sin, Start: 3456, End: 3459
# Token: exudados, Start: 3460, End: 3468
# Token: cardiovascular, Start: 3470, End: 3484
# Token: auscultacion, Start: 3486, End: 3498
# Token: cardiaca, Start: 3499, End: 3507
# Token: con, Start: 3508, End: 3511
# Token: tonos, Start: 3512, End: 3517
# Token: ritmicos, Start: 3518, End: 3526
# Token: y, Start: 3527, End: 3528
# Token: sin, Start: 3529, End: 3532
# Token: soplos, Start: 3533, End: 3539
# Token: no, Start: 3541, End: 3543
# Token: edemas, Start: 3544, End: 3550
# Token: en, Start: 3551, End: 3553
# Token: miembros, Start: 3554, End: 3562
# Token: inferiores, Start: 3563, End: 3573
# Token: ni, Start: 3574, End: 3576
# Token: lesiones, Start: 3577, End: 3585
# Token: cutaneas, Start: 3586, End: 3594
# Token: respiratorio, Start: 3596, End: 3608
# Token: auscultacion, Start: 3610, End: 3622
# Token: respiratoria, Start: 3623, End: 3635
# Token: con, Start: 3636, End: 3639
# Token: murmullo, Start: 3640, End: 3648
# Token: vesicular, Start: 3649, End: 3658
# Token: conservado, Start: 3659, End: 3669
# Token: sin, Start: 3671, End: 3674
# Token: ruidos, Start: 3675, End: 3681
# Token: patologicos, Start: 3682, End: 3693
# Token: anadidos, Start: 3694, End: 3702
# Token: abdomen, Start: 3704, End: 3711
# Token: no, Start: 3713, End: 3715
# Token: distendido, Start: 3716, End: 3726
# Token: blando, Start: 3728, End: 3734
# Token: y, Start: 3735, End: 3736
# Token: depresible, Start: 3737, End: 3747
# Token: no, Start: 3749, End: 3751
# Token: doloroso, Start: 3752, End: 3760
# Token: a, Start: 3761, End: 3762
# Token: la, Start: 3763, End: 3765
# Token: palpacion, Start: 3766, End: 3775
# Token: no, Start: 3777, End: 3779
# Token: se, Start: 3780, End: 3782
# Token: palpan, Start: 3783, End: 3789
# Token: masas, Start: 3790, End: 3795
# Token: ni, Start: 3796, End: 3798
# Token: megalias, Start: 3799, End: 3807
# Token: ni, Start: 3809, End: 3811
# Token: tampoco, Start: 3812, End: 3819
# Token: globo, Start: 3820, End: 3825
# Token: vesical, Start: 3826, End: 3833
# Token: no, Start: 3835, End: 3837
# Token: signos, Start: 3838, End: 3844
# Token: de, Start: 3845, End: 3847
# Token: irritacion, Start: 3848, End: 3858
# Token: peritoneal, Start: 3859, End: 3869
# Token: punopercusion, Start: 3871, End: 3884
# Token: lumbar, Start: 3885, End: 3891
# Token: bilateral, Start: 3892, End: 3901
# Token: negativa, Start: 3902, End: 3910
# Token: neurologico, Start: 3912, End: 3923
# Token: vigil, Start: 3925, End: 3930
# Token: y, Start: 3931, End: 3932
# Token: orientada, Start: 3933, End: 3942
# Token: en, Start: 3943, End: 3945
# Token: las, Start: 3946, End: 3949
# Token: tres, Start: 3950, End: 3954
# Token: esferas, Start: 3955, End: 3962
# Token: no, Start: 3964, End: 3966
# Token: alteraciones, Start: 3967, End: 3979
# Token: del, Start: 3980, End: 3983
# Token: lenguaje, Start: 3984, End: 3992
# Token: no, Start: 3994, End: 3996
# Token: signos, Start: 3997, End: 4003
# Token: de, Start: 4004, End: 4006
# Token: focalidad, Start: 4007, End: 4016
# Token: neurologica, Start: 4017, End: 4028
# Token: aparentes, Start: 4029, End: 4038
# Token: exploracio, Start: 4040, End: 4050
# Token: complementaria, Start: 4051, End: 4065
# Token: ecg, Start: 4066, End: 4069
# Token: taquicardia, Start: 4072, End: 4083
# Token: sinusal, Start: 4084, End: 4091
# Token: a, Start: 4092, End: 4093
# Token: 130lpm, Start: 4094, End: 4100
# Token: pr, Start: 4102, End: 4104
# Token: 120, Start: 4105, End: 4108
# Token: mseg, Start: 4109, End: 4113
# Token: qrs, Start: 4115, End: 4118
# Token: 80mseg, Start: 4119, End: 4125
# Token: eje, Start: 4127, End: 4130
# Token: 0o, Start: 4131, End: 4134
# Token: sin, Start: 4135, End: 4138
# Token: alteraciones, Start: 4139, End: 4151
# Token: agudas, Start: 4152, End: 4158
# Token: en, Start: 4159, End: 4161
# Token: la, Start: 4162, End: 4164
# Token: repolarizacion, Start: 4165, End: 4179
# Token: rx, Start: 4181, End: 4183
# Token: torax, Start: 4184, End: 4189
# Token: indice, Start: 4192, End: 4198
# Token: cardiotoracico, Start: 4199, End: 4213
# Token: no, Start: 4214, End: 4216
# Token: aumentado, Start: 4217, End: 4226
# Token: lt05, Start: 4229, End: 4235
# Token: senos, Start: 4238, End: 4243
# Token: costofrenicos, Start: 4244, End: 4257
# Token: libres, Start: 4258, End: 4264
# Token: no, Start: 4266, End: 4268
# Token: condensaciones, Start: 4269, End: 4283
# Token: parenquimatosas, Start: 4284, End: 4299
# Token: eab, Start: 4301, End: 4304
# Token: ph, Start: 4306, End: 4308
# Token: 737, Start: 4309, End: 4313
# Token: pco2, Start: 4315, End: 4319
# Token: 41mmhg, Start: 4320, End: 4326
# Token: sodio, Start: 4328, End: 4333
# Token: 133mmol, Start: 4334, End: 4341
# Token: l, Start: 4342, End: 4343
# Token: potasio, Start: 4345, End: 4352
# Token: 36mmol, Start: 4353, End: 4360
# Token: l, Start: 4361, End: 4362
# Token: cloro, Start: 4364, End: 4369
# Token: 99mmol, Start: 4370, End: 4376
# Token: l, Start: 4377, End: 4378
# Token: calcio, Start: 4380, End: 4386
# Token: 454mg, Start: 4387, End: 4393
# Token: dl, Start: 4394, End: 4396
# Token: glucosa, Start: 4398, End: 4405
# Token: 100mg, Start: 4406, End: 4411
# Token: dl, Start: 4412, End: 4414
# Token: lactato, Start: 4416, End: 4423
# Token: 26mmol, Start: 4424, End: 4431
# Token: l, Start: 4432, End: 4433
# Token: hb, Start: 4435, End: 4437
# Token: 149g, Start: 4438, End: 4443
# Token: dl, Start: 4444, End: 4446
# Token: be, Start: 4448, End: 4450
# Token: 16mmol, Start: 4451, End: 4459
# Token: l, Start: 4460, End: 4461
# Token: hco3, Start: 4463, End: 4467
# Token: 237mmol, Start: 4468, End: 4476
# Token: l, Start: 4477, End: 4479
# Token: analitica, Start: 4480, End: 4489
# Token: hb, Start: 4491, End: 4493
# Token: 141g, Start: 4494, End: 4499
# Token: dl, Start: 4500, End: 4502
# Token: hcto, Start: 4504, End: 4508
# Token: 419, Start: 4509, End: 4514
# Token: vcm, Start: 4516, End: 4519
# Token: 864fl, Start: 4520, End: 4526
# Token: leucocitos, Start: 4528, End: 4538
# Token: 2580, Start: 4539, End: 4543
# Token: can, Start: 4545, End: 4548
# Token: 100, Start: 4549, End: 4552
# Token: cal, Start: 4554, End: 4557
# Token: 1600, Start: 4558, End: 4562
# Token: cam, Start: 4564, End: 4567
# Token: 900, Start: 4568, End: 4571
# Token: plaquetas, Start: 4573, End: 4582
# Token: 169000, Start: 4583, End: 4589
# Token: tp, Start: 4591, End: 4593
# Token: ratio, Start: 4595, End: 4600
# Token: 152, Start: 4602, End: 4606
# Token: quick, Start: 4608, End: 4613
# Token: 53, Start: 4614, End: 4617
# Token: inr, Start: 4619, End: 4622
# Token: 151, Start: 4623, End: 4627
# Token: ttpa, Start: 4629, End: 4633
# Token: ratio, Start: 4635, End: 4640
# Token: 121, Start: 4642, End: 4646
# Token: fibrinogeno, Start: 4648, End: 4659
# Token: 373g, Start: 4660, End: 4665
# Token: l, Start: 4666, End: 4667
# Token: glucosa, Start: 4669, End: 4676
# Token: 102mg, Start: 4677, End: 4682
# Token: dl, Start: 4683, End: 4685
# Token: urea, Start: 4687, End: 4691
# Token: 37mg, Start: 4692, End: 4696
# Token: dl, Start: 4697, End: 4699
# Token: creatinina, Start: 4701, End: 4711
# Token: 105mg, Start: 4712, End: 4718
# Token: dl, Start: 4719, End: 4721
# Token: sodio, Start: 4723, End: 4728
# Token: 1326mmol, Start: 4729, End: 4738
# Token: l, Start: 4739, End: 4740
# Token: potasio, Start: 4742, End: 4749
# Token: 410mmol, Start: 4750, End: 4758
# Token: l, Start: 4759, End: 4760
# Token: cloro, Start: 4762, End: 4767
# Token: 99mmol, Start: 4768, End: 4774
# Token: l, Start: 4775, End: 4776
# Token: calcio, Start: 4778, End: 4784
# Token: 92mg, Start: 4785, End: 4790
# Token: dl, Start: 4791, End: 4793
# Token: ast, Start: 4795, End: 4798
# Token: 20ui, Start: 4799, End: 4803
# Token: l, Start: 4804, End: 4805
# Token: alt, Start: 4807, End: 4810
# Token: 17ui, Start: 4811, End: 4815
# Token: l, Start: 4816, End: 4817
# Token: proteina, Start: 4819, End: 4827
# Token: 81g, Start: 4828, End: 4832
# Token: dl, Start: 4833, End: 4835
# Token: pcr, Start: 4837, End: 4840
# Token: 779mg, Start: 4841, End: 4847
# Token: dl, Start: 4848, End: 4850
# Token: hemocultivos, Start: 4852, End: 4864
# Token: en, Start: 4866, End: 4868
# Token: curso, Start: 4869, End: 4874
# Token: nhc, Start: 4876, End: 4879
# Token: agevinf, Start: 4902, End: 4911
# Token: 24, Start: 4912, End: 4915
# Token: lopd, Start: 4916, End: 4920
# Token: frotis, Start: 4921, End: 4927
# Token: virus, Start: 4928, End: 4933
# Token: respiratorios, Start: 4934, End: 4947
# Token: negativo, Start: 4949, End: 4957
# Token: gripe, Start: 4958, End: 4963
# Token: a, Start: 4964, End: 4965
# Token: b, Start: 4967, End: 4968
# Token: y, Start: 4969, End: 4970
# Token: vrs, Start: 4971, End: 4974
# Token: positivo, Start: 4976, End: 4984
# Token: para, Start: 4985, End: 4989
# Token: adenovirus, Start: 4990, End: 5000
# Token: frotis, Start: 5002, End: 5008
# Token: rectal, Start: 5009, End: 5015
# Token: y, Start: 5016, End: 5017
# Token: faringeo, Start: 5018, End: 5026
# Token: ets, Start: 5027, End: 5030
# Token: pendiente, Start: 5032, End: 5041
# Token: sedimento, Start: 5043, End: 5052
# Token: orina, Start: 5053, End: 5058
# Token: leucocitos, Start: 5060, End: 5070
# Token: 154, Start: 5071, End: 5075
# Token: ul, Start: 5076, End: 5078
# Token: eritrocitos, Start: 5080, End: 5091
# Token: 61, Start: 5092, End: 5095
# Token: ul, Start: 5096, End: 5098
# Token: celulas, Start: 5100, End: 5107
# Token: epiteliales, Start: 5108, End: 5119
# Token: 05, Start: 5120, End: 5123
# Token: ul, Start: 5124, End: 5126
# Token: cilindros, Start: 5128, End: 5137
# Token: hialinos, Start: 5138, End: 5146
# Token: 046, Start: 5147, End: 5151
# Token: ul, Start: 5152, End: 5154
# Token: bacterias, Start: 5156, End: 5165
# Token: 270, Start: 5166, End: 5169
# Token: ul, Start: 5170, End: 5172
# Token: hongos, Start: 5174, End: 5180
# Token: negativo, Start: 5181, End: 5189
# Token: urocultivo, Start: 5191, End: 5201
# Token: negativo, Start: 5203, End: 5211
# Token: serologias, Start: 5213, End: 5223
# Token: 203, Start: 5225, End: 5229
# Token: mycoplasma, Start: 5232, End: 5242
# Token: pneumoniae, Start: 5243, End: 5253
# Token: igm, Start: 5254, End: 5257
# Token: positivo, Start: 5258, End: 5266
# Token: igg, Start: 5267, End: 5270
# Token: negativo, Start: 5271, End: 5279
# Token: veb, Start: 5281, End: 5284
# Token: igm, Start: 5285, End: 5288
# Token: negativo, Start: 5289, End: 5297
# Token: igg, Start: 5298, End: 5301
# Token: positivo, Start: 5302, End: 5310
# Token: cmv, Start: 5312, End: 5315
# Token: igm, Start: 5316, End: 5319
# Token: negativo, Start: 5320, End: 5328
# Token: igg, Start: 5329, End: 5332
# Token: positivo, Start: 5333, End: 5341
# Token: parvovirus, Start: 5343, End: 5353
# Token: b19, Start: 5354, End: 5357
# Token: igm, Start: 5358, End: 5361
# Token: positivo, Start: 5362, End: 5370
# Token: igg, Start: 5371, End: 5374
# Token: positivo, Start: 5375, End: 5383
# Token: analitica, Start: 5385, End: 5394
# ...
# Token: lid, Start: 6478, End: 6481
# Token: se, Start: 6483, End: 6485
# Token: orienta, Start: 6486, End: 6493
# Token: como, Start: 6494, End: 6498
# Token: insuficiencia, Start: 6499, End: 6512
# Token: respiratoria, Start: 6513, End: 6525
# Token: aguda, Start: 6526, End: 6531
# Token: en, Start: 6532, End: 6534
# Token: contexto, Start: 6535, End: 6543
# Token: de, Start: 6544, End: 6546
# Token: neumonia, Start: 6547, End: 6555
# Token: basal, Start: 6556, End: 6561
# Token: derecha, Start: 6562, End: 6569
# Token: con, Start: 6571, End: 6574
# Token: probable, Start: 6575, End: 6583
# Token: componente, Start: 6584, End: 6594
# Token: de, Start: 6595, End: 6597
# Token: insuficiencia, Start: 6598, End: 6611
# Token: cardiaca, Start: 6612, End: 6620
# Token: asociado, Start: 6621, End: 6629
# Token: se, Start: 6631, End: 6633
# Token: mantiene, Start: 6634, End: 6642
# Token: soporte, Start: 6643, End: 6650
# Token: ventilatorio, Start: 6651, End: 6663
# Token: antibioticoterapia, Start: 6665, End: 6683
# Token: empirica, Start: 6684, End: 6692
# Token: tratamiento, Start: 6694, End: 6705
# Token: diuretico, Start: 6706, End: 6715
# Token: corticoideo, Start: 6717, End: 6728
# Token: y, Start: 6729, End: 6730
# Token: broncodilatador, Start: 6731, End: 6746
# Token: durante, Start: 6749, End: 6756
# Token: su, Start: 6757, End: 6759
# Token: estancia, Start: 6760, End: 6768
# Token: en, Start: 6769, End: 6771
# Token: urgencias, Start: 6772, End: 6781
# Token: el, Start: 6782, End: 6784
# Token: paciente, Start: 6785, End: 6793
# Token: presenta, Start: 6794, End: 6802
# Token: lenta, Start: 6803, End: 6808
# Token: evolucion, Start: 6809, End: 6818
# Token: clinica, Start: 6819, End: 6826
# Token: con, Start: 6828, End: 6831
# Token: mejoria, Start: 6832, End: 6839
# Token: de, Start: 6840, End: 6842
# Token: la, Start: 6843, End: 6845
# Token: hipercapnia, Start: 6846, End: 6857
# Token: y, Start: 6858, End: 6859
# Token: del, Start: 6860, End: 6863
# Token: trabajo, Start: 6864, End: 6871
# Token: respiratorio, Start: 6872, End: 6884
# Token: pudiendo, Start: 6886, End: 6894
# Token: disminuir, Start: 6895, End: 6904
# Token: fio2, Start: 6905, End: 6909
# Token: hasta, Start: 6910, End: 6915
# Token: retirada, Start: 6916, End: 6924
# Token: de, Start: 6925, End: 6927
# Token: vmni, Start: 6928, End: 6932
# Token: pero, Start: 6934, End: 6938
# Token: con, Start: 6939, End: 6942
# Token: necesidad, Start: 6943, End: 6952
# Token: posterior, Start: 6953, End: 6962
# Token: de, Start: 6963, End: 6965
# Token: cnaf, Start: 6966, End: 6970
# Token: el, Start: 6972, End: 6974
# Token: control, Start: 6975, End: 6982
# Token: radiologico, Start: 6983, End: 6994
# Token: no, Start: 6995, End: 6997
# Token: muestra, Start: 6998, End: 7005
# Token: mejoria, Start: 7006, End: 7013
# Token: de, Start: 7014, End: 7016
# Token: la, Start: 7017, End: 7019
# Token: condensacion, Start: 7020, End: 7032
# Token: pulmonar, Start: 7033, End: 7041
# Token: observandose, Start: 7043, End: 7055
# Token: infiltrados, Start: 7056, End: 7067
# Token: bilaterales, Start: 7068, End: 7079
# Token: se, Start: 7081, End: 7083
# Token: mantiene, Start: 7084, End: 7092
# Token: tratamiento, Start: 7093, End: 7104
# Token: instaurado, Start: 7105, End: 7115
# Token: e, Start: 7116, End: 7117
# Token: ingresa, Start: 7118, End: 7125
# Token: en, Start: 7126, End: 7128
# Token: planta, Start: 7129, End: 7135
# Token: de, Start: 7136, End: 7138
# Token: hospitalizacion, Start: 7139, End: 7154
# Token: a, Start: 7156, End: 7157
# Token: su, Start: 7158, End: 7160
# Token: llegada, Start: 7161, End: 7168
# Token: a, Start: 7169, End: 7170
# Token: planta, Start: 7171, End: 7177
# Token: de, Start: 7178, End: 7180
# Token: m, Start: 7181, End: 7183
# Token: interna, Start: 7184, End: 7191
# Token: el, Start: 7192, End: 7194
# Token: paciente, Start: 7195, End: 7203
# Token: refiere, Start: 7204, End: 7211
# Token: discreta, Start: 7212, End: 7220
# Token: mejoria, Start: 7221, End: 7228
# Token: clinica, Start: 7229, End: 7236
# Token: si, Start: 7238, End: 7240
# Token: bien, Start: 7241, End: 7245
# Token: su, Start: 7246, End: 7248
# Token: evolucion, Start: 7249, End: 7258
# Token: inciial, Start: 7259, End: 7266
# Token: fue, Start: 7267, End: 7270
# Token: torpida, Start: 7271, End: 7278
# Token: durante, Start: 7280, End: 7287
# Token: su, Start: 7288, End: 7290
# Token: estancia, Start: 7291, End: 7299
# Token: en, Start: 7300, End: 7302
# Token: planta, Start: 7303, End: 7309
# Token: el, Start: 7310, End: 7312
# Token: paciente, Start: 7313, End: 7321
# Token: ha, Start: 7322, End: 7324
# Token: permanecido, Start: 7325, End: 7336
# Token: hemodinnamicamente, Start: 7337, End: 7355
# Token: estable, Start: 7356, End: 7363
# Token: aunque, Start: 7365, End: 7371
# Token: con, Start: 7372, End: 7375
# Token: lenta, Start: 7376, End: 7381
# Token: recuperacion, Start: 7382, End: 7394
# Token: d, Start: 7395, End: 7396
# Token: elas, Start: 7397, End: 7401
# Token: saturaciones, Start: 7402, End: 7414
# Token: el, Start: 7416, End: 7418
# Token: paciente, Start: 7419, End: 7427
# Token: completo, Start: 7428, End: 7436
# Token: tratameinto, Start: 7437, End: 7448
# Token: antibiotico, Start: 7449, End: 7460
# Token: con, Start: 7461, End: 7464
# Token: meropenem, Start: 7465, End: 7474
# Token: pudiendo, Start: 7476, End: 7484
# Token: finalmente, Start: 7485, End: 7495
# Token: iniciar, Start: 7496, End: 7503
# Token: tratameinto, Start: 7504, End: 7515
# Token: con, Start: 7516, End: 7519
# Token: rehabilitacion, Start: 7520, End: 7534
# Token: desde, Start: 7536, End: 7541
# Token: el, Start: 7542, End: 7544
# Token: punto, Start: 7545, End: 7550
# Token: de, Start: 7551, End: 7553
# Token: vista, Start: 7554, End: 7559
# Token: respiratorio, Start: 7560, End: 7572
# Token: el, Start: 7574, End: 7576
# Token: paciente, Start: 7577, End: 7585
# Token: ha, Start: 7586, End: 7588
# Token: sgeuido, Start: 7589, End: 7596
# Token: una, Start: 7597, End: 7600
# Token: lenta, Start: 7601, End: 7606
# Token: pero, Start: 7608, End: 7612
# Token: buena, Start: 7613, End: 7618
# Token: recuperacion, Start: 7619, End: 7631
# Token: dada, Start: 7633, End: 7637
# Token: la, Start: 7638, End: 7640
# Token: fragilidad, Start: 7641, End: 7651
# Token: del, Start: 7652, End: 7655
# Token: paciente, Start: 7656, End: 7664
# Token: y, Start: 7666, End: 7667
# Token: dada, Start: 7668, End: 7672
# Token: la, Start: 7673, End: 7675
# Token: estabilizacion, Start: 7676, End: 7690
# Token: del, Start: 7691, End: 7694
# Token: hemograma, Start: 7695, End: 7704
# Token: por, Start: 7706, End: 7709
# Token: el, Start: 7710, End: 7712
# Token: momento, Start: 7713, End: 7720
# Token: no, Start: 7721, End: 7723
# Token: se, Start: 7724, End: 7726
# Token: hamn, Start: 7727, End: 7731
# Token: realizado, Start: 7732, End: 7741
# Token: nuevos, Start: 7742, End: 7748
# Token: estudios, Start: 7749, End: 7757
# Token: al, Start: 7759, End: 7761
# Token: alta, Start: 7762, End: 7766
# Token: es, Start: 7767, End: 7769
# Token: citado, Start: 7770, End: 7776
# Token: a, Start: 7777, End: 7778
# Token: ccee, Start: 7779, End: 7783
# Token: de, Start: 7784, End: 7786
# Token: medicina, Start: 7787, End: 7795
# Token: intrena, Start: 7796, End: 7803
# Token: para, Start: 7804, End: 7808
# Token: control, Start: 7809, End: 7816
# Token: evolutivo, Start: 7817, End: 7826
# Token: dada, Start: 7828, End: 7832
# Token: lo, Start: 7833, End: 7835
# Token: prolongado, Start: 7836, End: 7846
# Token: del, Start: 7847, End: 7850
# Token: ingreso, Start: 7851, End: 7858
# Token: y, Start: 7859, End: 7860
# Token: encamaminto, Start: 7861, End: 7872
# Token: se, Start: 7874, End: 7876
# Token: decide, Start: 7877, End: 7883
# Token: traslado, Start: 7884, End: 7892
# Token: al, Start: 7893, End: 7895
# Token: hospital, Start: 7896, End: 7904
# Token: pere, Start: 7905, End: 7909
# Token: virgili, Start: 7910, End: 7917
# Token: para, Start: 7918, End: 7922
# Token: recuperacion, Start: 7923, End: 7935
# Token: orientacio, Start: 7937, End: 7947
# Token: diagnostica, Start: 7948, End: 7959
# Token: 1, Start: 7960, End: 7961
# Token: neumonia, Start: 7963, End: 7971
# Token: adquirida, Start: 7972, End: 7981
# Token: en, Start: 7982, End: 7984
# Token: la, Start: 7985, End: 7987
# Token: comunidad, Start: 7988, End: 7997
# Token: fine, Start: 7998, End: 8002
# Token: iv, Start: 8003, End: 8005
# Token: e, Start: 8006, End: 8007
# Token: insuficiencia, Start: 8008, End: 8021
# Token: respiratoria, Start: 8022, End: 8034
# Token: aguda, Start: 8035, End: 8040
# Token: insuficiencia, Start: 8044, End: 8057
# Token: cardiaca, Start: 8058, End: 8066
# Token: de, Start: 8067, End: 8069
# Token: inicio, Start: 8070, End: 8076
# Token: reciente, Start: 8077, End: 8085
# Token: de, Start: 8086, End: 8088
# Token: etiologia, Start: 8089, End: 8098
# Token: multifactorial, Start: 8099, End: 8113
# Token: valvular, Start: 8115, End: 8123
# Token: hipertensiva, Start: 8125, End: 8137
# Token: anemia, Start: 8139, End: 8145
# Token: edema, Start: 8149, End: 8154
# Token: agudo, Start: 8155, End: 8160
# Token: de, Start: 8161, End: 8163
# Token: pulmon, Start: 8164, End: 8170
# Token: 3, Start: 8172, End: 8173
# Token: bicitopenia, Start: 8175, End: 8186
# Token: anemia, Start: 8189, End: 8195
# Token: normocitica, Start: 8196, End: 8207
# Token: normocromica, Start: 8208, End: 8220
# Token: leucopenia, Start: 8222, End: 8232
# Token: 4, Start: 8235, End: 8236
# Token: fibrilacion, Start: 8238, End: 8249
# Token: auricular, Start: 8250, End: 8259
# Token: lenta, Start: 8260, End: 8265
# Token: a, Start: 8266, End: 8267
# Token: 70, Start: 8268, End: 8270
# Token: ppm, Start: 8271, End: 8274
# Token: en, Start: 8276, End: 8278
# Token: tratamiento, Start: 8279, End: 8290
# Token: antocoagulante, Start: 8291, End: 8305
# Token: con, Start: 8306, End: 8309
# Token: enoxaparina, Start: 8310, End: 8321
# Token: 40mg12horas, Start: 8322, End: 8334
# Token: s, Start: 8336, End: 8337
# Token: procediments, Start: 8338, End: 8350
# Token: 8952, Start: 8351, End: 8356
# Token: electrocardiograma, Start: 8357, End: 8375
# Token: ecg, Start: 8377, End: 8380
# Token: nos, Start: 8381, End: 8384
# Token: ecg, Start: 8386, End: 8389
# Token: amb, Start: 8391, End: 8394
# Token: 12, Start: 8395, End: 8397
# Token: o, Start: 8398, End: 8399
# Token: mes, Start: 8400, End: 8403
# Token: derivacions, Start: 8404, End: 8415
# Token: ventilacion, Start: 8417, End: 8428
# Token: con, Start: 8429, End: 8432
# Token: optiblow, Start: 8433, End: 8441
# Token: rehabilitacion, Start: 8442, End: 8456
# Token: respiratoira, Start: 8457, End: 8469
# Token: rehabilitacion, Start: 8470, End: 8484
# Token: motora, Start: 8485, End: 8491
# Token: tractament, Start: 8493, End: 8503
# Token: i, Start: 8504, End: 8505
# Token: recomanacions, Start: 8506, End: 8519
# Token: a, Start: 8520, End: 8521
# Token: lalta, Start: 8522, End: 8528
# Token: omeprazol, Start: 8529, End: 8538
# Token: 20, Start: 8539, End: 8541
# Token: mg, Start: 8541, End: 8543
# Token: 1comprimido, Start: 8544, End: 8555
# Token: cada, Start: 8556, End: 8560
# Token: 24, Start: 8561, End: 8563
# Token: horas, Start: 8564, End: 8569
# Token: antes, Start: 8570, End: 8575
# Token: del, Start: 8576, End: 8579
# Token: desayuno, Start: 8580, End: 8588
# Token: polietilenglicol, Start: 8590, End: 8606
# Token: sales, Start: 8609, End: 8614
# Token: minerales, Start: 8615, End: 8624
# Token: 138, Start: 8625, End: 8629
# Token: g, Start: 8629, End: 8630
# Token: sobre, Start: 8631, End: 8636
# Token: si, Start: 8638, End: 8640
# Token: precisa, Start: 8641, End: 8648
# Token: insul, Start: 8650, End: 8655
# Token: aspart, Start: 8656, End: 8662
# Token: novorapid, Start: 8663, End: 8672
# Token: flexpen, Start: 8673, End: 8680
# Token: 100ui, Start: 8681, End: 8686
# Token: ml, Start: 8687, End: 8689
# Token: 3ml, Start: 8690, End: 8693
# Token: segun, Start: 8694, End: 8699
# Token: glicemia, Start: 8700, End: 8708
# Token: enoxaparina, Start: 8710, End: 8721
# Token: 40mg, Start: 8722, End: 8727
# Token: 04, Start: 8728, End: 8731
# Token: jeringuilla, Start: 8732, End: 8743
# Token: subcutanea, Start: 8744, End: 8754
# Token: cada, Start: 8755, End: 8759
# Token: 12horas, Start: 8760, End: 8767
# Token: doxazosina, Start: 8769, End: 8779
# Token: 4, Start: 8780, End: 8781
# Token: mg, Start: 8781, End: 8783
# Token: 2comprimidos, Start: 8784, End: 8796
# Token: cada, Start: 8797, End: 8801
# Token: 24, Start: 8802, End: 8804
# Token: horas, Start: 8805, End: 8810
# Token: cena, Start: 8812, End: 8816
# Token: amlodipina, Start: 8819, End: 8829
# Token: 10, Start: 8830, End: 8832
# Token: mg, Start: 8832, End: 8834
# Token: 1, Start: 8836, End: 8837
# Token: comprimido, Start: 8838, End: 8848
# Token: cada, Start: 8849, End: 8853
# Token: 24, Start: 8854, End: 8856
# Token: horas, Start: 8857, End: 8862
# Token: enalapril, Start: 8864, End: 8873
# Token: 5, Start: 8874, End: 8875
# Token: mg, Start: 8875, End: 8877
# Token: 2, Start: 8878, End: 8879
# Token: comprimidos, Start: 8880, End: 8891
# Token: cada, Start: 8892, End: 8896
# Token: 24, Start: 8897, End: 8899
# Token: horas, Start: 8900, End: 8905
# Token: prednisina, Start: 8907, End: 8917
# Token: 10, Start: 8918, End: 8920
# Token: mg, Start: 8920, End: 8922
# Token: 1, Start: 8923, End: 8924
# Token: comprimido, Start: 8925, End: 8935
# Token: cada, Start: 8936, End: 8940
# Token: 24, Start: 8941, End: 8943
# Token: horas, Start: 8944, End: 8949
# Token: nhc, Start: 8951, End: 8954
# Token: agevmir, Start: 8977, End: 8986
# Token: 34, Start: 8987, End: 8990
# Token: lopd, Start: 8991, End: 8995
# Token: metamizol, Start: 8996, End: 9005
# Token: 575, Start: 9006, End: 9009
# Token: mg, Start: 9010, End: 9012
# Token: 2, Start: 9014, End: 9015
# Token: comprimidos, Start: 9016, End: 9027
# Token: cada, Start: 9028, End: 9032
# Token: 8, Start: 9033, End: 9034
# Token: horas, Start: 9035, End: 9040
# Token: si, Start: 9041, End: 9043
# Token: precisa, Start: 9044, End: 9051
# Token: paracetamol, Start: 9053, End: 9064
# Token: 1, Start: 9065, End: 9066
# Token: g, Start: 9066, End: 9067
# Token: cada, Start: 9068, End: 9072
# Token: 8, Start: 9073, End: 9074
# Token: horas, Start: 9075, End: 9080
# Token: si, Start: 9081, End: 9083
# Token: precisa, Start: 9084, End: 9091
# Token: risperidona, Start: 9093, End: 9104
# Token: 1, Start: 9105, End: 9106
# Token: mg, Start: 9106, End: 9108
# Token: por, Start: 9109, End: 9112
# Token: la, Start: 9113, End: 9115
# Token: noche, Start: 9116, End: 9121
# Token: bromuro, Start: 9123, End: 9130
# Token: de, Start: 9131, End: 9133
# Token: ipatropio, Start: 9134, End: 9143
# Token: 500mcg2ml, Start: 9144, End: 9154
# Token: sol, Start: 9155, End: 9158
# Token: nebu, Start: 9159, End: 9163
# Token: cada, Start: 9164, End: 9168
# Token: 6, Start: 9169, End: 9170
# Token: horas, Start: 9171, End: 9176
# Token: fisiologico, Start: 9179, End: 9190
# Token: 10, Start: 9191, End: 9193
# Token: ml, Start: 9194, End: 9196
# Token: ampolla, Start: 9197, End: 9204
# Token: de, Start: 9205, End: 9207
# Token: plastico, Start: 9208, End: 9216
# Token: dieta, Start: 9218, End: 9223
# Token: complemetaria, Start: 9224, End: 9237
# Token: normocalorica, Start: 9238, End: 9251
# Token: hipermetabolica, Start: 9252, End: 9267
# Token: con, Start: 9268, End: 9271
# Token: fibra, Start: 9272, End: 9277
# Token: diabetico, Start: 9278, End: 9287
# Token: 220, Start: 9288, End: 9291
# Token: ml, Start: 9292, End: 9294
# Token: frasco, Start: 9295, End: 9301
# Token: cada, Start: 9302, End: 9306
# Token: 8, Start: 9307, End: 9308
# Token: horas, Start: 9309, End: 9314
# Token: control, Start: 9316, End: 9323
# Token: acudira, Start: 9324, End: 9331
# Token: a, Start: 9332, End: 9333
# Token: ccee, Start: 9334, End: 9338
# Token: de, Start: 9339, End: 9341
# Token: meidcina, Start: 9342, End: 9350
# Token: interna, Start: 9351, End: 9358
# Token: dr, Start: 9360, End: 9362
# Token: el, Start: 9379, End: 9381
# Token: dia, Start: 9382, End: 9385
# Token: 170818, Start: 9386, End: 9394
# Token: traer, Start: 9396, End: 9401
# Token: una, Start: 9402, End: 9405
# Token: analitica, Start: 9406, End: 9415
# Token: general, Start: 9416, End: 9423
# Token: realizada, Start: 9424, End: 9433
# Token: los, Start: 9434, End: 9437
# Token: dias, Start: 9438, End: 9442
# Token: previos, Start: 9443, End: 9450
# Token: a, Start: 9451, End: 9452
# Token: la, Start: 9453, End: 9455
# Token: cita, Start: 9456, End: 9460
# Token: destinacio, Start: 9462, End: 9472
# Token: a, Start: 9473, End: 9474
# Token: lalta, Start: 9475, End: 9481
# Token: soci, Start: 9483, End: 9487

# %% [markdown]
# **Pre-processing json object**
#
# - Reading the json object to obtain a list of the Negation and Uncertainty proc words as well as their scopes
#
# - The scopes and annotations will be used for the supervised learning as the 'target'

# %%
# Loading the json object
loading = open("negacio_test_v2024.json", encoding="utf-8")
for_object = loading.read()
object = json.loads(for_object)

# %%
# Prepare lists to store the results
negations = []
negation_scopes = []
uncertainties = []
uncertainty_scopes = []

# Process the documents and obtain negation and uncertainty annotations
for item in object:
    text_data = item['data']['text']
    for prediction in item['predictions']:
        for result in prediction['result']:
            labels = result['value']['labels']
            start_index = result['value']['start']
            end_index = result['value']['end']
            text_segment = item['data']['text'][start_index:end_index]

            if "NEG" in labels:
                negations.append(text_segment)

                # Find the scope of the negation
                scope_start = -1
                scope_end = -1

                # Search for the scope starting just after the negation
                current_index = prediction['result'].index(result)
                if current_index < len(prediction['result']) - 1:
                    next_result = prediction['result'][current_index + 1]
                    next_start = next_result['value']['start']
                    next_end = next_result['value']['end']
                    next_labels = next_result['value']['labels']
                    if "NSCO" in next_labels and next_start == end_index:
                        scope_start = next_start
                        scope_end = next_end

                current_index = prediction['result'].index(result)
                if current_index > 0:
                    prev_result = prediction['result'][current_index - 1]
                    prev_start = prev_result['value']['start']
                    prev_end = prev_result['value']['end']
                    prev_labels = prev_result['value']['labels']
                    if "NSCO" in prev_labels and prev_end == start_index:
                        scope_start = prev_start
                        scope_end = prev_end

                if scope_start != -1 and scope_end != -1:
                    scope_text = item['data']['text'][scope_start:scope_end]
                    negation_scopes.append((start_index, scope_end))

            if "UNC" in labels:
                uncertainties.append(text_segment)

                # Find the scope of the uncertainty
                scope_start = -1
                scope_end = -1

                # Search for the scope starting just after the uncertainty
                current_index = prediction['result'].index(result)
                if current_index < len(prediction['result']) - 1:
                    next_result = prediction['result'][current_index + 1]
                    next_start = next_result['value']['start']
                    next_end = next_result['value']['end']
                    next_labels = next_result['value']['labels']
                    if "USCO" in next_labels and next_start == end_index:
                        scope_start = next_start
                        scope_end = next_end

                current_index = prediction['result'].index(result)
                if current_index > 0:
                    prev_result = prediction['result'][current_index - 1]
                    prev_start = prev_result['value']['start']
                    prev_end = prev_result['value']['end']
                    prev_labels = prev_result['value']['labels']
                    if "USCO" in prev_labels and prev_end == start_index:
                        scope_start = prev_start
                        scope_end = prev_end

                if scope_start != -1 and scope_end != -1:
                    scope_text = item['data']['text'][scope_start:scope_end]
                    uncertainty_scopes.append((start_index, scope_end))

# Remove whitespaces from negations and uncertainties if they are at the end
negations = [negation.rstrip() for negation in negations]
uncertainties = [uncertainty.rstrip() for uncertainty in uncertainties]
# Remove duplicates from the annotation lists
negations = list(set(negations))
negation_scopes = list(set(negation_scopes))
uncertainties = list(set(uncertainties))
uncertainty_scopes = list(set(uncertainty_scopes))



# Print the negation/uncertainty annotations and their scopes
print("Negations\n", negations)
print("Negation Scopes\n", negation_scopes)
print("Uncertainties\n", uncertainties)
print("Uncertainty Scopes\n", uncertainty_scopes)
# Out:
# Negations
#  ['negativos', 'negativa', 'ex-fumador', 'nega', ' afebril', 'negatiu', 'afebril.', 'afebril,', 'descartan', 'asintomatica', 'insuficiencia', 'asintomatico', 'desorientada', 'ni', 'ausente,', 'desorientada,', 'neg', 'falta de', 'incapacidad', 'no', 'retirar', 'nula', 'sense', 'negativo', 'exfumador', 'asintomatico.', 'ausencia de', 'sin', 'tampoco', 'niega', 'imposibilidad de', 'negativas', 'inespecifico,', 'descarta', 'neg.', 'retirado.', 'niegan', 'inestabilidad', 'ex', 'inespecifica.', 'afebril', 'negativa.', 'desconocen', 'negativos.', 'inespecifico.', 'cede', 'retiro']
# Negation Scopes
#  [(926, 952), (2207, 2230), (1218, 1218), (11293, 11360), (1798, 1811), (2559, 2574), (1731, 1748), (3840, 3852), (2211, 2223), (432, 439), (874, 882), (3997, 4028), (453, 489), (3393, 3406), (4654, 4697), (3555, 3575), (5537, 5566), (2054, 2132), (3684, 3707), (2498, 2517), (5275, 5309), (377, 377), (829, 861), (1689, 1737), (401, 438), (762, 807), (981, 1022), (2712, 2738), (3643, 3656), (3123, 3141), (3111, 3185), (4655, 4675), (1430, 1472), (2830, 2869), (2668, 2718), (2221, 2267), (464, 471), (4171, 4207), (7254, 7271), (3945, 3962), (2720, 2755), (2613, 2629), (3133, 3171), (6297, 6309), (505, 526), (2554, 2570), (1635, 1635), (2136, 2164), (3487, 3534), (3569, 3585), (2919, 2933), (10488, 10499), (12195, 12285), (1748, 1804), (5130, 5155), (4378, 4406), (4610, 4640), (1881, 1897), (1172, 1199), (2664, 2679), (1981, 1993), (2664, 2688), (4303, 4339), (482, 501), (4633, 4641), (1114, 1114), (1996, 2018), (5212, 5257), (884, 917), (3967, 3999), (3576, 3601), (9576, 9608), (5156, 5194), (7175, 7225), (2678, 2698), (7977, 7992), (5946, 5984), (1299, 1299), (9649, 9686), (1252, 1294), (1863, 1884), (4299, 4337), (3246, 3313), (3052, 3070), (7112, 7150), (1213, 1213), (3229, 3269), (2243, 2281), (4964, 4992), (1586, 1602), (1042, 1111), (385, 423), (4714, 4728), (2933, 2983), (5327, 5327), (3535, 3564), (6995, 7042), (2889, 2922), (641, 641), (4640, 4653), (1929, 1955), (4620, 4665), (333, 372), (342, 350), (1153, 1203), (2120, 2187), (6832, 6858), (1774, 1797), (1062, 1075), (1704, 1720), (1223, 1276), (1254, 1254), (1455, 1500), (3096, 3112), (5103, 5187), (818, 827), (1016, 1071), (4530, 4587), (2549, 2561), (3519, 3578), (2903, 2919), (4328, 4363), (1503, 1531), (1659, 1671), (3301, 3337), (3003, 3015), (4883, 4890), (2892, 2918), (3675, 3691), (6803, 6817), (1083, 1093), (972, 1015), (866, 866), (1036, 1036), (3463, 3538), (2209, 2232), (629, 648), (2854, 2936), (858, 858), (1670, 1685), (2840, 2867), (1482, 1494), (3728, 3805), (9508, 9570), (4058, 4134), (433, 458), (4771, 4802), (395, 422), (1215, 1244), (1112, 1133), (1127, 1140), (1227, 1227), (798, 812), (378, 378), (444, 472), (4096, 4111), (4364, 4429), (1320, 1320), (939, 954), (381, 388), (3040, 3054), (3283, 3297), (1142, 1142), (2943, 2981), (4480, 4505), (432, 457), (2444, 2470), (573, 603), (5074, 5100), (3013, 3054), (2691, 2765), (5823, 5852), (5543, 5578), (3814, 3853), (5065, 5136), (5289, 5289), (1209, 1209), (4401, 4427), (7872, 7905), (1373, 1406), (6019, 6046), (2220, 2245), (2519, 2541), (4014, 4026), (6073, 6111), (5216, 5273), (3788, 3814), (3810, 3823), (5048, 5060), (1308, 1308), (657, 691), (3289, 3343), (9069, 9081), (749, 774), (3818, 3854), (5188, 5201), (7149, 7178), (2673, 2711), (1023, 1041), (391, 428), (2463, 2492), (424, 452), (5235, 5263), (3914, 3930), (509, 541), (4689, 4726), (3619, 3631), (2562, 2582), (4060, 4105), (4371, 4403), (1121, 1171), (535, 562), (9873, 9885), (4674, 4714), (5641, 5653), (5638, 5666), (406, 443), (391, 391), (5040, 5064), (6601, 6634), (1332, 1359), (2540, 2558), (376, 393), (1853, 1893), (457, 457), (3987, 3999), (2148, 2164), (1229, 1229), (6159, 6159), (693, 706), (2189, 2201), (7432, 7442), (4229, 4300), (5460, 5501), (5035, 5047), (1516, 1547), (1794, 1820), (1254, 1281), (2309, 2351), (5220, 5250), (1469, 1498), (1963, 1979), (2055, 2071), (3949, 4003), (6272, 6296), (2004, 2016), (3063, 3083), (365, 373), (4957, 4979), (10755, 10765), (7443, 7460), (597, 625), (3437, 3455), (629, 657), (2889, 2921), (1020, 1054), (5740, 5765), (8062, 8093), (2143, 2169), (1313, 1330), (11982, 12031), (2475, 2508), (9225, 9263), (6504, 6533), (2985, 3024), (4459, 4459), (2679, 2679), (471, 471), (3410, 3423), (1088, 1104), (5082, 5099), (380, 380), (5670, 5687), (4090, 4103), (4100, 4135), (6241, 6271), (1042, 1082), (3015, 3015), (882, 882), (1154, 1170), (729, 743), (6098, 6114), (678, 688), (3609, 3636), (1191, 1191), (1411, 1469), (600, 634), (723, 723), (9531, 9543), (5259, 5302), (4340, 4367), (2756, 2768), (8 ...
# Uncertainties
#  ['se desestima', 'aparente', 'desconocido', 'no sabe', 'posibles', 'sugestivo de', 'dudosa', 'sin poder descartar', 'sospechosa de', 'sin claro', 'sugestivos de', 'sin clara', 'no', 'pudiendo', 'posiblemente', 'compatibles con', 'probable', 'sin', 'posible', 'aparentemente', 'sospechar', 'aparente.', 'sugieren', 'se orienta', 'no aparente', 'se comprueba', 'poco sugestivo de', 'sugestivas de', 'dudosamente', 'no permite descartar', 'puede', 'dudoso', 'dificil descartar', 'orienta', 'sugestiva como', 'podria', 'sospecha de', 'probablemente', 'sugestiva de', 'sugiere', 'parece', 'valorar', 'compatible con', 'vs', '??']
# Uncertainty Scopes
#  [(2821, 2837), (9771, 9885), (1989, 2007), (1167, 1197), (2988, 3005), (10931, 10992), (11032, 11032), (2678, 2708), (1413, 1429), (2219, 2261), (9077, 9116), (3118, 3211), (1986, 2022), (2730, 2730), (666, 697), (1980, 1991), (4689, 4728), (9504, 9534), (5376, 5438), (861, 893), (10153, 10153), (2635, 2690), (3945, 3974), (3067, 3110), (764, 796), (10126, 10184), (2919, 2952), (8635, 8721), (4563, 4590), (955, 985), (6351, 6404), (868, 910), (4407, 4440), (2026, 2081), (623, 648), (2520, 2543), (1392, 1449), (10782, 10884), (9660, 9751), (1718, 1738), (1505, 1539), (8910, 8927), (3039, 3080), (1717, 1749), (846, 881), (11049, 11084), (6299, 6343), (6483, 6570), (2606, 2624), (6101, 6151), (1798, 1840), (11144, 11165), (1870, 1929), (2952, 2952), (1490, 1516), (2677, 2714), (1893, 1921), (1548, 1585), (6684, 6745), (5948, 5977), (476, 520), (8908, 8952), (1828, 1849), (9341, 9392), (6575, 6630), (346, 364), (1531, 1555), (5250, 5281), (9429, 9452), (10992, 10992), (7080, 7124), (1026, 1113), (662, 699), (9757, 9786), (2780, 2803), (2165, 2206), (4406, 4448), (692, 724), (1930, 1958), (3009, 3031), (1480, 1520), (1516, 1516), (2751, 2827), (6886, 6916), (1732, 1759), (7074, 7104), (12242, 12296), (2518, 2558), (5998, 6032), (10143, 10153), (1290, 1307), (7564, 7614), (2653, 2730), (1189, 1242), (2523, 2547), (3024, 3113), (8861, 8903), (7448, 7640), (2641, 2667), (3111, 3138), (6409, 6453), (11495, 11539), (1635, 1657), (3957, 4003), (2634, 2673), (421, 469), (1780, 1858), (9931, 10000), (1469, 1490), (2827, 2860)]

# %% [markdown]
# **Implementation**
# ____________________________________________________________

# %% [markdown]
# Medical Words

# %%
#MEDICAL WORDS FROM TRAINING SET + MANUALY ADDED
med_words = ['secuelas', 'positivo','positiva','cuadro','patron', 'terapeutico', 'mejora', 'terapia', 'alteracion', 'reaccion', 'farmacoterapias', 'malestares', 'anormalidades', 'indicacion', 'desordenes', 'lesiones', 'farmacoterapia', 'respuesta', 'sindromes', 'desviaciones', 'sensibilidad', 'diagnostico', 'tratamiento', 'dolor', 'examenes', 'molestias', 'farmacoterapeutico', 'deterioros', 'enfermedad', 'exposicion', 'resultado', 'riesgo', 'sintomas', 'deficiencia', 'efecto', 'toxicos', 'eficacia', 'toxicidad', 'presencia', 'inmunidad', 'tratamientos', 'discapacidades', 'danos', 'intolerancia', 'deformidades', 'prevencion', 'afecciones', 'rechazo', 'lesion', 'examen', 'farmacoterapeuticos', 'farmacos', 'patologias', 'dolencias', 'diagnosticos', 'prueba', 'analisis', 'complicaciones', 'patologia', 'anomalias', 'infecciones', 'disfunciones', 'padecimientos', 'progresion', 'agravamientos', 'infeccion', 'efectos', 'nivel', 'sintoma', 'condicion', 'trastornos', 'pruebas', 'farmacologico', 'sindrome', 'concentracion', 'capacidad', 'hallazgo', 'secuela', 'afectaciones', 'inflamacion', 'manifestaciones', 'deteccion', 'enfermedades', 'dolores', 'signo', 'funcion', 'complicacion', 'adversidades', 'resistencia', 'problemas', 'absorcion']

# %% [markdown]
# Negation Words / Phrases

# %%
#EXTRACTED FROM THE TRAINING SET
neg_pre = ['impide', 'exfumador', 'negativo', 'desaparecen', 'asintomatica', 'afebril', 'se desestimo', 'negativos', 'ninguno', 'asintomatico', 'desorientado', 'inestabilidad', 'atipicos', 'ausencia de', 'ceden', 'negativa', 'negativas', 'excepto', 'desorientacion', 'inespecificos', 'se suspende','inespecifico', 'ex', 'arritmicos', 'cede', 'se retira', 'ex fumador', 'niegan', 'negatiu', 'negaitvo', 'indetectable',' negativo', 'suspendido']
neg_pos = ['retirar','ni' 'desaparicion de', 'descarta', 'ausencia', 'descartada', 'niega', 'nega', 'rechaza', 'desaparicion del', 'imposibilidad', 'retiro', 'irregulares', 'negatividad', 'tampoco', 'sin', 'imposibilidad de', 'en ninguna', 'incapacidad para', ' no', 'neg', ' afebril', 'sense', 'falta de', 'negatividad de', 'negatividad del', 'no']

# %%
#EXTRACTED FROM THE GITHUB
neg_pre_filtered= ['gobierna al paciente', 'ninguna otra evidencia', 'la van descartar per', 'no aparece', 'descartaron al paciente por', 'adecuado para descartarla', 'excluir', 'excloure', 'descartar al pacient per', 'sin ninguna evidencia de', 'descartarlo por', 'no tenía', 'lo descartó', 'sin signo de', 'sense indicació de', 'pot descartar', 'excluye', 'ho descarta', 'ninguna evidencia radiográfica de', 'descartarlo', 'negando', 'sense troballes de', 'adequat per a descartar-lo', 'cap senyal de', 'no em queixo de', 'ninguna señal de', 'nunca tuve', 'ho va descartar', 'descartar', 'lo descartaron por', 'la va descartar contra', 'pot descartar-ho', 'lo descartaron en contra', 'libre de', 'pot descartar al pacient', 'no tinc', 'absència de', 'sin quejas de', 'van descartar contra', 'la va descartar', 'no tenia', 'descartado contra', 'ho va descartar contra', 'no me quejo de', 'puede descartar', 'no significativo', 'resuelto', 'puede descartar al paciente', 'no sospitós', 'gens especial per a', 'pot descartar-ho per', 'exclou', 'r / o', 'resolt', 'van descartar per a', 'descartó', 'va descartar', 'puede descartarla contra', 'sin evidencia', 'descartar per a', 'no apareix', 'pot descartar-la per', 'la descartó', 'va descartar al pacient', 'descartar-ho', 'cap altra evidència', 'no saber de', 'ninguna nueva evidencia', 'sin indicación de', 'mai desenvolupat', 'sense queixes de', "l'exclou", 'lo descarta', 'cap suggeriment de', 'cap evidència radiogràfica de', 'sense cap evidència de', 'puede descartarlo', 'pacient no era', 'no apreciar', 'con ningún', 'cap causa de', 'adecuado para descartarlo', 'no associat amb', 'descartarla', 'nunca desarrollado', 'adecuado para descartarla por', 'no poden veure', 'ro', 'ninguna evidencia para sugerir', 'sin hallazgos de', 'no pueden ver', 'pot descartar-la', 'la excluye', 'governa al pacient', 'amb cap', 'descartar al paciente por', 'expulsó al paciente por', 'no anormal', 'no sospechoso', 'pot descartar-la contra', 'nada nuevo', 'paciente no era', 'descartaron para', 'no poder', 'evaluar por', 'suficiente para descartarlo por', 'no exhibir', 'més aviat que', 'fer una prova per', 'puede descartarla por', 'ninguna causa de', 'lliure de', 'mai vaig tenir', 'no tengo', 'descartaron contra', 'puede descartarla', 'adecuado para descartarlo por', 'descartat contra', 'descartar-la', 'adequat per a descartar-la', 'no significatiu', 'negatiu per a', 'sense evidència', 'ho van descartar per', 'descartar al pacient', 'cap nova evidència', 'descartarla por', 'nada especial para', 'ninguna sugerencia de', 'sense signe de', 'no sentir', 'descartar al paciente', 'descartar-ho per', 'puede descartarlo en contra', 'puede descartarlo por', 'más bien que', 'res nou', 'descartó al paciente', 'negant', 'avaluar per', 'no demostrar', 'descartar para', 'no revela', 'no revelar', 'descartó al paciente contra', 'puede descartar contra', 'descartar-la per', 'suficiente para descartar', 'negativo para', 'la descartó contra', 'revisado para', 'suficient per a descartar', 'revisat per a', 'hacer una prueba por', 'pot descartar-ho en contra', 'pot descartar contra', 'la descartaron por', 'descartaron al paciente contra', 'no asociado con', 'suficiente para descartarla por', 'lo descartó contra']
neg_pos_filtered= ['libre', 'podría ser descartado', 'fue descartado', 'rechazado', 'ha de ser descartat', 'lliure', 'rebutjat', 'puede ser descartado', 'ser descartat', 'adecuado para descartar', 'están descartadas', 'podria ser descartat', 'improbable', 'podría ser descartado por', 'debe ser descartado por', 'suficient per a descartar-ho', 'serà descartat per', 'podria descartar-se', 'suficient per a descartar-la', 'va ser descartat', 'han estat descartades', 'ser descartado por', 'declina', 'adequat per a descartar', 'siendo descartado', 'suficiente para descartarla', 'no ver', 'sent descartat', 'està descartat', 'se puede descartar por', 'pot ser descartat', 'ha estat descartat', 'puede ser descartado para', 'ha de descartar-se', 'suficiente para descartarlo', 'es descarta', 'ha sido descartado', 'será descartado', 'ser descartado', 'no veure', 'ser descartat per', 'debe ser descartado', 'serà descartat', 'debe descartarse para', 'debe ser descartado para', 'es pot descartar per', 'negado', 'se descarta', 'lo descartaron', 'no ser', 'se puede descartar', 'está descartado', 'negat', 'podría descartarse', 'es pot descartar', 'ho van descartar', 'podria ser descartat per', 'han sido descartadas', 'será descartado por', 'estan descartades', 'debe descartarse']
neg_pre.extend(neg_pre_filtered)
neg_pos.extend(neg_pos_filtered)

# %% [markdown]
# Uncertainty Words / Phrases

# %%
#NOSE COM EMFOCAR: SIN, NO, DESCARTAR
unc_pre = [ 'al parecer' , 'vs', 'dudosamente', 'indeterminado', 'sospecha', 'pudieran', 'aparentes', 'dubtos','permite descartar', 'parece', 'atribuida', 'clara', 'no clara', 'desconocido']
unc_pos = ['compatible amb', 'desconoce', 'indiquen', 'sin aparente', 'sugieren', 'ssospechosas de', 'probablemente', 'posible', 'sugestivo de', 'falsa', 'sospechan de', 'posibilidad de', 'sugiriendo', 'orienta', 'sospechosos de', 'sugestivos de', 'se orienta', 'plantea', 'podria', 'puede', 'podrian', 'probables', 'no', 'sugiere', 'parecen', 'sin', 'sospechosa de', 'sugestivas de', 'orientan como', 'dudosa', 'interpreta', 'compatible con', 'valorar', 'dudosos', 'probable', 'poco porque', 'sugieran', 'sin clara', 'no permite descartar', 'se desconoce', 'impresiona de', 'sugestiva de', 'orienta como', 'orientan', 'sin poder descartar', 'no parece', 'sospitosa de', 'sugestivos con', 'impresiona', 'aparentemente', 'sospecha de', 'no es posible descartar', 'compatibles con', 'compatible', 'aparente', 'sugestiva como', 'posiblemente', 'posibles', 'sugiera de', 'descartar', 'dudoso', 'se orientan', 'sospechosas de', 'sin aparentes', 'sin claras']

# %%
#DEMA HO AFEGEIXO
unc_pre_filtered = ['como una causa secundaria para', 'como el origen secundario de', 'secundario a', 'como la causa de', 'como la causa secundaria de', 'como una razón de', 'como una causa secundaria de', 'como una etiología secundaria para', 'excepto', 'aunque', 'como la fuente secundaria para', 'como una etilogía para', 'como la fuente de', 'como el origen secundario para', 'com la font secundària de', 'como una razón secundaria para', 'com una raó secundària per a', 'com la font secundària per a', 'com una etiologia de', 'como una etiología secundaria de', 'secundari a', 'encara que', 'como una razón secundaria de', 'como la razón secundaria de', 'como la fuente secundaria de', 'com la causa secundària de', 'a pesar que', 'como una razón para', 'como la etilogía de', "com l'etiologia de", 'como la razón secundaria para', 'como un origen secundario para', 'com una font secundària per a', 'como una etilogía de', 'como fuente de', "com l'etiologia secundària per a", "com l'origen secundari per a", "com l'origen secundari de", 'però', 'com a causa de', 'com una etiologia secundària per a', 'como la razón de', 'com un origen secundari per a', 'com una raó secundària de', 'no obstant això', 'com una font secundària de', 'com una raó per a', 'pero', 'com la raó secundària de', 'como la etilogía secundaria para', 'a pesar de que', 'sin embargo', "com l'etiologia secundària de", 'com la causa de', 'com una causa secundària per a', 'com la raó de', 'a part de', 'como una fuente secundaria de', 'com una causa secundària de', 'aparte de', 'com a font de', 'como una fuente secundaria para', "com l'origen de", 'com una etiologia per a', 'com la raó secundària per a', 'como el origen de', 'com un origen secundari de', 'com una raó de', 'como un origen secundario de', 'excepte', 'como causa de', 'encara', 'todavía', 'com una etiologia secundària de', 'como la etilogía secundaria de']
unc_post_filtered =['origens de', 'raons de', 'altres possibilitats de', 'font per a', 'desencadenar evento para', 'origen para', 'raons per a', 'fuente para', 'causes de', 'fuentes de', 'causa de', 'etilogia de', 'etilogía para', 'origen per a', 'motivo de', 'fuentes para', 'otras posibilidades de', 'razones de', 'causas de', 'font de', 'razones para', 'etilogía de', 'fonts per a', 'fonts de', 'raó per a', 'razón de', 'orígenes para', 'razón para', 'motiu de', 'desencadenar esdeveniment per a', 'fuente de', 'orígenes de', 'origen de', 'raó de', 'etilogia per a', 'origens per a']
unc_pre.extend(unc_pre_filtered)
unc_pos.extend(unc_post_filtered)

# %% [markdown]
# Detect a Phrase

# %%
#FUNCTION TO DETECT A WORD / PHRASE MATCH
def phrase_matching(tokenized_text, word_or_phrases):
    text_length = len(tokenized_text)
    # Sort negation phrases by length in descending order
    word_or_phrases = sorted(word_or_phrases, key=len, reverse=True)
    for i in range(text_length):
        for phrase in word_or_phrases:
            phrase_tokens = phrase.split()
            phrase_length = len(phrase_tokens)
            if i + phrase_length <= text_length:  # Check if remaining tokens are enough to match the phrase
                joined_tokens = ' '.join([token[0] for token in tokenized_text[i:i+phrase_length]])
                if ' '.join(joined_tokens.split()) == phrase:  # Remove extra spaces and then check if consecutive tokens match the phrase
                        yield True, phrase, tokenized_text[i][1], tokenized_text[i+phrase_length-1][2]
                
    return False, None, None, None

# %% [markdown]
# Negation Detection

# %%
def negation_detection(processed_texts, neg_pre, neg_pos, medical_words, i=0):
    NEG = []
    NSCO = []
    for processed_text in processed_texts:
        for result in phrase_matching(processed_text, neg_pre+neg_pos):
            phrase_found, phrase, start_idx, end_idx = result
            if phrase_found:
                # Calculate the start token index
                if phrase in neg_pre:
                    start_token_index = max(next((i for i, token in enumerate(processed_text) if token[1] > start_idx), len(processed_text)) - 1, 0)
                    # Select the previous 5 tokens
                    previous_tokens = [token[0] for token in processed_text[max(start_token_index - 5, 0):start_token_index]]
                    for token in previous_tokens:
                        if token in medical_words:
                            # Append to NEG
                            NEG.append((token, phrase, start_idx, end_idx))
                            # Calculate start and end indices for NSCO
                            start_nsco = processed_text[max(start_token_index - 5, 0)][1]  # Start index of first token in previous_tokens
                            end_nsco = processed_text[start_token_index - 1][2]  # End index of last token in previous_tokens
                            # Append to NSCO
                            NSCO.append((start_nsco, end_nsco))
                    
                if phrase in neg_pos:
                    start_token_index = max(next((i for i, token in enumerate(processed_text) if token[1] > start_idx), len(processed_text)) - 1, 0)
                    # Select the next 5 tokens
                    next_tokens = [token[0] for token in processed_text[start_token_index + 1:min(start_token_index + 6, len(processed_text))]]
                    for token in next_tokens:
                        if token in medical_words:
                            # Append to NEG
                            NEG.append((phrase, start_idx, end_idx))
                            # Calculate start and end indices for NSCO
                            start_nsco = processed_text[start_token_index + 1][1] if start_token_index + 1 < len(processed_text) else processed_text[start_token_index][1]  # Start index of first token in next_tokens
                            end_nsco = processed_text[min(start_token_index + 5, len(processed_text) - 1)][2]  # End index of last token in next_tokens
                            # Append to NSCO
                            NSCO.append((start_nsco, end_nsco))
    return NEG, NSCO
            

neg_detect, neg_scope_detect = negation_detection(processed_texts, neg_pre, neg_pos, med_words)
print('Negations detected: \n',neg_detect)
print('Negations scopes detected: \n',neg_scope_detect)
#que solo sean del training set
# Out:
# Negations detected:
#  [('niega', 499, 504), ('riesgo', 'negativo', 1313, 1321), ('niega', 446, 451), ('niega', 446, 451), ('niega', 2001, 2006), ('niega', 2206, 2211), ('no', 2474, 2476), ('no', 2521, 2523), ('positivo', 'negativo', 5271, 5279), ('positivo', 'negativo', 5289, 5297), ('positivo', 'negativo', 5320, 5328), ('niega', 621, 626), ('sin', 2464, 2467), ('sin', 2821, 2824), ('signo', 'negativo', 4850, 4858), ('no', 5978, 5980), ('no', 6034, 6036), ('no', 6034, 6036), ('no', 6056, 6058), ('sin', 9787, 9790), ('no', 9843, 9845), ('sin', 481, 485), ('sin', 2352, 2355), ('sin', 4581, 4584), ('funcion', 'ausencia de', 5834, 5845), ('niega', 504, 510), ('no', 2010, 2012), ('ausencia', 2942, 2950), ('sin', 8429, 8432), ('sin', 9078, 9081), ('niega', 355, 360), ('niega', 380, 385), ('niega', 402, 407), ('positivo', 'negativo', 564, 572), ('sin', 1709, 1712), ('no', 1428, 1430), ('no', 1121, 1123), ('no', 2720, 2722), ('niega', 534, 540), ('sin', 690, 693), ('sin', 690, 693), ('sin', 6694, 6697), ('complicaciones', 'se suspende', 6724, 6735), ('no', 1135, 1137), ('sin', 1332, 1335), ('no', 1430, 1432), ('sin', 2210, 2213), ('sin', 2475, 2478), ('sin', 2840, 2843), ('sin', 2889, 2892), ('sin', 1343, 1346), ('no', 1908, 1910), ('resultado', 'negativo', 5045, 5053), ('positivo', 'negativo', 723, 731), ('no', 326, 328), ('no', 355, 357), ('sin', 2616, 2619), ('no', 2637, 2639), ('sin', 4677, 4680), ('sin', 4984, 4987), ('sin', 5216, 5219), ('sin', 8534, 8537), ('sin', 9480, 9483), ('sin', 9480, 9483), ('no', 629, 631), ('niega', 583, 588), ('no', 1193, 1195), ('no', 1209, 1211), ('no', 3990, 3992), ('sin', 6310, 6313), ('sin', 6848, 6851), ('sin', 6848, 6851), ('sin', 6993, 6996), ('sin', 490, 494), ('toxicos', 'exfumador', 533, 543), ('niega', 3229, 3234), ('niega', 3229, 3234), ('no', 5020, 5022), ('sin', 5035, 5038), ('sin', 5048, 5051), ('no', 458, 460), ('no', 439, 442), ('sin', 2454, 2457), ('niega', 4386, 4391), ('sin', 4517, 4520), ('sin', 6404, 6407), ('sin', 10457, 10460), ('sin', 11032, 11035), ('sin', 973, 976), ('ausencia', 1853, 1861), ('niega', 483, 488), ('no', 897, 899), ('no', 910, 912), ('neg', 1218, 1221), ('neg', 1227, 1230), ('neg', 1227, 1230), ('nega', 3609, 3613), ('sin', 460, 464), ('sin', 518, 522), ('tratamiento', 'suspendido', 857, 867), ('sin', 2613, 2616), ('sin', 4620, 4623), ('complicaciones', 'ausencia de', 4674, 4685), ('ausencia', 4674, 4682), ('niega', 460, 465), ('sin', 1932, 1935), ('no', 456, 458), ('sin', 1699, 1702), ('no', 629, 631), ('no', 629, 631), ('no', 406, 408), ('no', 600, 602), ('no', 600, 602), ('sin', 1127, 1130), ('libre', 799, 804), ('niega', 456, 461), ('no', 1105, 1107), ('sin', 1637, 1640), ('niega', 498, 503), ('no', 537, 539), ('sin', 2130, 2133), ('sin', 3205, 3208), ('niega', 2856, 2861), ('niega', 2870, 2875), ('niega', 2870, 2875), ('niega', 2892, 2897), ('sin', 3251, 3254), ('no', 6013, 6015), ('no', 432, 434), ('sin', 1233, 1236), ('no', 1280, 1282), ('niega', 449, 454), ('no', 698, 700), ('sin', 1282, 1285), ('positivo', 'negativo', 2436, 2444), ('toxicos', 'niegan', 423, 429), ('sin', 1739, 1742), ('sin', 1914, 1917), ('sin', 1996, 1999), ('no', 3840, 3842), ('sin', 5552, 5555), ('positivo', 'negativo', 6202, 6210), ('no', 7408, 7410), ('descarta', 11806, 11814), ('no', 458, 460), ('no', 1121, 1123), ('sin', 1411, 1414), ('no', 3003, 3005), ('no', 3015, 3017), ('sin', 3289, 3292), ('sin', 3555, 3558), ('sin', 3949, 3952), ('dolor', 'cede', 1910, 1914), ('no', 432, 434), ('no', 998, 1000), ('neg', 1229, 1232), ('neg', 1238, 1241), ('positivo', 'negativos', 2469, 2478), ('niega', 487, 493), ('sin', 3967, 3970), ('sin', 7432, 7435), ('niega', 1864, 1869), ('sin', 2097, 2100), ('sin', 963, 966), ('no', 1548, 1550), ('no', 443, 445), ('ausencia', 683, 691), ('no', 464, 466), ('no', 471, 473), ('niega', 1016, 1021), ('sin', 1503, 1506), ('sin', 573, 576), ('sin', 573, 576), ('sin', 2120, 2123), ('no', 2668, 2670), ('complicacion', 'ausencia de', 4301, 4312), ('sin', 6599, 6602), ('sin', 659 ...
# Negations scopes detected:
#  [(505, 551), (1277, 1312), (452, 502), (452, 502), (2007, 2049), (2212, 2242), (2477, 2500), (2524, 2563), (5232, 5270), (5258, 5288), (5289, 5319), (627, 662), (2468, 2493), (2825, 2859), (4815, 4849), (5981, 6007), (6037, 6073), (6037, 6073), (6059, 6098), (9791, 9823), (9846, 9877), (486, 542), (2356, 2380), (4585, 4625), (5793, 5833), (511, 559), (2013, 2056), (2951, 2995), (8433, 8462), (9082, 9128), (361, 401), (386, 414), (408, 444), (537, 563), (1713, 1748), (1431, 1482), (1124, 1163), (2723, 2757), (541, 589), (694, 750), (694, 750), (6698, 6747), (6681, 6722), (1138, 1171), (1336, 1380), (1433, 1471), (2214, 2253), (2479, 2541), (2844, 2888), (2893, 2954), (1347, 1388), (1911, 1950), (5006, 5044), (682, 722), (329, 373), (358, 403), (2620, 2663), (2640, 2684), (4681, 4732), (4988, 5040), (5220, 5272), (8538, 8567), (9484, 9524), (9484, 9524), (632, 660), (589, 636), (1196, 1234), (1212, 1271), (3993, 4041), (6314, 6347), (6852, 6877), (6852, 6877), (6997, 7025), (495, 543), (490, 531), (3235, 3278), (3235, 3278), (5023, 5057), (5039, 5062), (5052, 5077), (461, 510), (443, 492), (2458, 2500), (4392, 4432), (4521, 4549), (6408, 6445), (10461, 10502), (11036, 11078), (977, 1018), (1862, 1885), (489, 528), (900, 933), (913, 946), (1223, 1247), (1232, 1258), (1232, 1258), (3614, 3665), (465, 511), (523, 567), (817, 855), (2617, 2659), (4624, 4670), (4636, 4673), (4683, 4706), (466, 505), (1936, 1971), (459, 498), (1703, 1738), (632, 660), (632, 660), (409, 447), (603, 626), (603, 626), (1131, 1164), (805, 843), (462, 501), (1108, 1149), (1641, 1676), (504, 545), (540, 594), (2134, 2169), (3209, 3240), (2862, 2897), (2876, 2917), (2876, 2917), (2898, 2944), (3255, 3284), (6016, 6066), (435, 466), (1237, 1268), (1283, 1322), (455, 494), (701, 739), (1286, 1312), (2401, 2435), (383, 421), (1743, 1782), (1918, 1959), (2000, 2042), (3843, 3883), (5556, 5599), (6155, 6200), (7411, 7447), (11815, 11850), (461, 510), (1124, 1159), (1415, 1446), (3006, 3054), (3018, 3077), (3293, 3342), (3559, 3592), (3953, 4002), (1887, 1909), (435, 469), (1001, 1038), (1233, 1256), (1242, 1264), (2429, 2468), (494, 550), (3971, 4029), (7436, 7471), (1870, 1902), (2101, 2124), (967, 1014), (1551, 1589), (446, 481), (692, 714), (467, 495), (474, 514), (1022, 1070), (1507, 1542), (577, 636), (577, 636), (2124, 2167), (2671, 2705), (4268, 4299), (6603, 6641), (6603, 6641), (435, 467), (1819, 1860), (2724, 2762), (361, 403), (2676, 2700)]

# %% [markdown]
# Uncertainity Detection

# %%
def uncertainity_detection(processed_texts, unc_pre, unc_pos, medical_words, i=0):
    UNC = []
    USCO = []
    for processed_text in processed_texts:
        for result in phrase_matching(processed_text, unc_pre+unc_pos):
            phrase_found, phrase, start_idx, end_idx = result
            if phrase_found:
                # Calculate the start token index
                if phrase in unc_pre:
                    start_token_index = max(next((i for i, token in enumerate(processed_text) if token[1] > start_idx), len(processed_text)) - 1, 0)
                    # Select the previous 5 tokens
                    previous_tokens = [token[0] for token in processed_text[max(start_token_index - 5, 0):start_token_index]]
                    for token in previous_tokens:
                        if token in medical_words:
                            # Append to NEG
                            UNC.append((token, phrase, start_idx, end_idx))
                            # Calculate start and end indices for NSCO
                            start_usco = processed_text[max(start_token_index - 5, 0)][1]  # Start index of first token in previous_tokens
                            end_usco = processed_text[start_token_index - 1][2]  # End index of last token in previous_tokens
                            # Append to NSCO
                            USCO.append((start_usco, end_usco))
                    
                if phrase in unc_pos:
                    start_token_index = max(next((i for i, token in enumerate(processed_text) if token[1] > start_idx), len(processed_text)) - 1, 0)
                    # Select the next 5 tokens
                    next_tokens = [token[0] for token in processed_text[start_token_index + 1:min(start_token_index + 6, len(processed_text))]]
                    for token in next_tokens:
                        if token in medical_words:
                            # Append to NEG
                            UNC.append((phrase, start_idx, end_idx))
                            # Calculate start and end indices for NSCO
                            start_usco = processed_text[start_token_index + 1][1] if start_token_index + 1 < len(processed_text) else processed_text[start_token_index][1]  # Start index of first token in next_tokens
                            end_usco = processed_text[min(start_token_index + 5, len(processed_text) - 1)][2]  # End index of last token in next_tokens
                            # Append to NSCO
                            USCO.append((start_usco, end_usco))
    print(UNC)
    print(USCO)
    print(len(UNC))
    return UNC, USCO
            

unc_detect, unc_detect_scopes = uncertainity_detection(processed_texts, unc_pre, unc_pos, med_words)
# Out:
# [('no', 2474, 2476), ('no', 2521, 2523), ('descartar', 5653, 5662), ('sin', 2464, 2467), ('sin', 2821, 2824), ('no', 5978, 5980), ('puede', 5984, 5989), ('no', 6034, 6036), ('no', 6034, 6036), ('no', 6056, 6058), ('sin', 9787, 9790), ('no', 9843, 9845), ('se orienta', 9931, 9941), ('orienta como', 9934, 9946), ('orienta', 9934, 9941), ('sin', 481, 485), ('sin', 2352, 2355), ('sin', 4581, 4584), ('riesgo', 'aunque', 8138, 8144), ('diagnostico', 'sospecha', 764, 772), ('no', 2010, 2012), ('sin', 8429, 8432), ('sin', 9078, 9081), ('sin', 1709, 1712), ('no', 1428, 1430), ('no', 1121, 1123), ('no', 2720, 2722), ('sin', 690, 693), ('sin', 690, 693), ('sin', 6694, 6697), ('no', 1135, 1137), ('sin', 1332, 1335), ('no', 1430, 1432), ('sin', 2210, 2213), ('sin', 2475, 2478), ('sin', 2840, 2843), ('sin', 2889, 2892), ('sin', 1343, 1346), ('no', 1908, 1910), ('nivel', 'parece', 2350, 2356), ('no', 326, 328), ('no', 355, 357), ('sin', 2616, 2619), ('no', 2637, 2639), ('sin', 4677, 4680), ('sin', 4984, 4987), ('sin', 5216, 5219), ('sin', 8534, 8537), ('sin', 9480, 9483), ('sin', 9480, 9483), ('no', 629, 631), ('no', 1193, 1195), ('no', 1209, 1211), ('no', 3990, 3992), ('sin', 6310, 6313), ('sin', 6848, 6851), ('sin', 6848, 6851), ('sin', 6993, 6996), ('sin', 490, 494), ('no', 5020, 5022), ('sin', 5035, 5038), ('sin', 5048, 5051), ('probable', 7583, 7591), ('no', 458, 460), ('probable', 476, 484), ('no', 439, 442), ('orienta', 1356, 1363), ('sugestivo de', 1831, 1843), ('sin', 2454, 2457), ('sin', 4517, 4520), ('sin', 6404, 6407), ('sin', 10457, 10460), ('sin poder descartar', 11032, 11051), ('sin', 11032, 11035), ('descartar', 11042, 11051), ('descartar', 11042, 11051), ('podria', 11495, 11501), ('sin', 973, 976), ('no', 897, 899), ('no', 910, 912), ('sin', 460, 464), ('sin', 518, 522), ('sin', 2613, 2616), ('sin', 4620, 4623), ('sin', 1932, 1935), ('no', 456, 458), ('sin', 1699, 1702), ('no', 629, 631), ('no', 629, 631), ('no', 406, 408), ('no', 600, 602), ('no', 600, 602), ('sin', 1127, 1130), ('no', 1105, 1107), ('sin', 1637, 1640), ('no', 537, 539), ('sin', 2130, 2133), ('sin', 3205, 3208), ('sin', 3251, 3254), ('no', 6013, 6015), ('no', 432, 434), ('sin', 1233, 1236), ('no', 1280, 1282), ('no', 698, 700), ('sin', 1282, 1285), ('valorar', 1718, 1725), ('sin claras', 1739, 1749), ('sin', 1739, 1742), ('sin', 1914, 1917), ('sin aparente', 1996, 2008), ('sin', 1996, 1999), ('aparente', 2000, 2008), ('no', 3840, 3842), ('sin', 5552, 5555), ('probable', 6299, 6307), ('no', 7408, 7410), ('no', 458, 460), ('no', 1121, 1123), ('sin', 1411, 1414), ('no', 3003, 3005), ('no', 3015, 3017), ('compatible con', 3067, 3081), ('compatible', 3067, 3077), ('sin', 3289, 3292), ('sin', 3555, 3558), ('sin', 3949, 3952), ('no', 432, 434), ('no', 998, 1000), ('posibles', 2653, 2661), ('sin', 3967, 3970), ('sin', 7432, 7435), ('sin', 2097, 2100), ('sin', 963, 966), ('no permite descartar', 1548, 1568), ('no', 1548, 1550), ('descartar', 1559, 1568), ('no', 443, 445), ('no', 464, 466), ('no', 471, 473), ('sin', 1503, 1506), ('sin', 573, 576), ('sin', 573, 576), ('sin', 2120, 2123), ('sugestivos de', 2144, 2157), ('no', 2668, 2670), ('sugieren', 3039, 3047), ('sin', 6599, 6602), ('sin', 6599, 6602), ('no', 432, 434), ('no', 1816, 1818), ('sin', 357, 360), ('no', 2673, 2675), ('impresiona de', 2676, 2689), ('impresiona', 2676, 2686)]
# [(2477, 2500), (2524, 2563), (5663, 5706), (2468, 2493), (2825, 2859), (5981, 6007), (5990, 6016), (6037, 6073), (6037, 6073), (6059, 6098), (9791, 9823), (9846, 9877), (9934, 9980), (9942, 9993), (9942, 9993), (486, 542), (2356, 2380), (4585, 4625), (8097, 8136), (729, 763), (2013, 2056), (8433, 8462), (9082, 9128), (1713, 1748), (1431, 1482), (1124, 1163), (2723, 2757), (694, 750), (694, 750), (6698, 6747), (1138, 1171), (1336, 1380), (1433, 1471), (2214, 2253), (2479, 2541), (2844, 2888), (2893, 2954), (1347, 1388), (1911, 1950), (2319, 2349), (329, 373), (358, 403), (2620, 2663), (2640, 2684), (4681, 4732), (4988, 5040), (5220, 5272), (8538, 8567), (9484, 9524), (9484, 9524), (632, 660), (1196, 1234), (1212, 1271), (3993, 4041), (6314, 6347), (6852, 6877), (6852, 6877), (6997, 7025), (495, 543), (5023, 5057), (5039, 5062), (5052, 5077), (7592, 7629), (461, 510), (485, 527), (443, 492), (1364, 1388), (1841, 1882), (2458, 2500), (4521, 4549), (6408, 6445), (10461, 10502), (11036, 11078), (11036, 11078), (11052, 11096), (11052, 11096), (11502, 11538), (977, 1018), (900, 933), (913, 946), (465, 511), (523, 567), (2617, 2659), (4624, 4670), (1936, 1971), (459, 498), (1703, 1738), (632, 660), (632, 660), (409, 447), (603, 626), (603, 626), (1131, 1164), (1108, 1149), (1641, 1676), (540, 594), (2134, 2169), (3209, 3240), (3255, 3284), (6016, 6066), (435, 466), (1237, 1268), (1283, 1322), (701, 739), (1286, 1312), (1726, 1766), (1743, 1782), (1743, 1782), (1918, 1959), (2000, 2042), (2000, 2042), (2009, 2045), (3843, 3883), (5556, 5599), (6308, 6342), (7411, 7447), (461, 510), (1124, 1159), (1415, 1446), (3006, 3054), (3018, 3077), (3078, 3109), (3078, 3109), (3293, 3342), (3559, 3592), (3953, 4002), (435, 469), (1001, 1038), (2662, 2710), (3971, 4029), (7436, 7471), (2101, 2124), (967, 1014), (1551, 1589), (1551, 1589), (1569, 1603), (446, 481), (467, 495), (474, 514), (1507, 1542), (577, 636), (577, 636), (2124, 2167), (2155, 2190), (2671, 2705), (3048, 3079), (6603, 6641), (6603, 6641), (435, 467), (1819, 1860), (361, 403), (2676, 2700), (2687, 2710), (2687, 2710)]
# 154

# %% [markdown]
# **Results**

# %%
def remove_punctuation_and_spaces(text):
    # Define translation table to remove punctuation and spaces
    translation_table = str.maketrans("", "", string.punctuation + " ")

    # Remove punctuation and spaces from the text using translate method
    cleaned_text = text.translate(translation_table)
    
    return cleaned_text

# Remove punctuation and spaces from each element in the list
negations = [remove_punctuation_and_spaces(item) for item in negations]
# Remove punctuation and spaces from each element in the list
uncertainties = [remove_punctuation_and_spaces(item) for item in uncertainties]

# %%
#Convert the negations tuple into a list with just the negation words detected.
neg_detections_text = []
for detection in neg_detect:
    for x in detection:
        if type(x)== str:
            neg_detections_text.append(x)

#Convert the uncertainty tuple into a list with just the negation words detected.
unc_detections_text = []
for detection in unc_detect:
    for x in detection:
        if type(x)== str:
            unc_detections_text.append(x)


def precision_neg_unc(true, pred):
    right = 0
    total_pred = len(pred)

    for token in pred:
        if token in true:
            right += 1

    precision = right / total_pred
    return precision

def calcular_recall(y_true, y_pred):
    # Initialize a counter to track the number of correct predictions.
    num_correctos = 0
    # Get the total number of true words.
    total_palabras = len(y_true)

    # Loop through each true token.
    for token in y_true:
        # If the text of the true token is in the texts of the predicted tokens, increment the count of correct predictions.
        if any(token == pred_token for pred_token in y_pred):
            num_correctos += 1

    # Calculate recall as the proportion of correct predictions out of total actual positives.
    recall = num_correctos / total_palabras if total_palabras > 0 else 0
    # Return the calculated recall.
    return recall

def calcular_f1_score(precision, recall):
    if precision + recall == 0:
        return 0
    else:
        f1_score = 2 * (precision * recall) / (precision + recall)
        return f1_score

precision_neg= precision_neg_unc(negations, neg_detections_text)
recall_neg = calcular_recall(negations, neg_detections_text)
f1_neg = calcular_f1_score(precision_neg, recall_neg)

# %%
precision_unc= precision_neg_unc(uncertainties, unc_detections_text)
recall_unc = calcular_recall(uncertainties, unc_detections_text)
f1_unc = calcular_f1_score(precision_unc, recall_unc)

# %%
def precision_neg_scopes(true_scopes, pred_scopes):
    right = 0
    total_pred = len(pred_scopes) #Total amount of predictions.

    for prediction in pred_scopes:
        pred_start, pred_end = prediction[0], prediction[1]

        for true in true_scopes:
            true_start, true_end = true[0], true[1]
            if (pred_start == true_start or pred_end == true_end): 
                right += 1
            elif abs(pred_start - true_start) <= 10 and abs(pred_end - true_end) <= 10: #using abs to get the absolute number and see if the pred matches true.
                right += 0.5
            

    precision = right / total_pred
    return precision

def calcular_recall_scopes(y_true_scopes, y_pred_scopes):
    # Initialize a counter to track the number of correct scope predictions.
    num_aciertos = 0
    # Get the total number of true scopes.
    total_predicciones = len(y_true_scopes)

    # Loop through each true scope.
    for true_scope in y_true_scopes:
        # Then loop through each predicted scope.
        for pred_scope in y_pred_scopes:
            # Extract the start and end indices from the true and predicted scopes.
            true_num1, true_num2 = true_scope
            pred_num1, pred_num2 = pred_scope
            # If both the start and end of the true scope are within 10 units of the predicted scope's start and end, 
            # increment the count of correct predictions.
            if abs(true_num1 - pred_num1) <= 10 and abs(true_num2 - pred_num2) <= 10:
                num_aciertos += 1
                # Break out of the inner loop if we find a match.
                break

    # Calculate recall as the proportion of correct predictions out of total actual positives.
    recall = num_aciertos / total_predicciones if total_predicciones > 0 else 0
    # Return the calculated recall.
    return recall

precision_neg_scope= precision_neg_scopes(negation_scopes, neg_scope_detect)
recall_neg_scope = calcular_recall_scopes(negation_scopes, neg_scope_detect)
f1_neg_scope = calcular_f1_score(precision_neg_scope, recall_neg_scope)

# %%
def precision_unc_scopes(true_scopes, pred_scopes):
    right = 0
    total_pred = len(pred_scopes)

    for prediction in pred_scopes:
        pred_start, pred_end = prediction[0], prediction[1]

        for true in true_scopes:
            true_start, true_end = true[0], true[1]
            if (pred_start == true_start or pred_end == true_end):
                right += 2
            elif abs(pred_start - true_start) <= 12 and abs(pred_end - true_end) <= 12:
                right += 1

    precision = right / total_pred

    return precision

precision_unc_scope = precision_unc_scopes(uncertainty_scopes, unc_detect_scopes)
recall_unc_scope = calcular_recall_scopes(uncertainty_scopes, unc_detect_scopes)
f1_score_unc_scope = calcular_f1_score(precision_unc_scope, recall_unc_scope)

# %%
print('PRECISIONS:  ')
print('Precision for Negations: ', precision_neg)
print('-------------------------------------------')
print('Precision for Negation scopes: ', precision_neg_scope)
print('-------------------------------------------')
print('Precision for Uncertanties: ', precision_unc)
print('-------------------------------------------')
print('Precision for Uncertanties scopes: ', precision_unc_scope)

print('\nRECALL:  ')
print('Recall for Negations: ', recall_neg)
print('-------------------------------------------')
print('Recall for Negation scopes: ', recall_neg_scope)
print('-------------------------------------------')
print('Reall for Uncertanties: ', recall_unc)
print('-------------------------------------------')
print('Recall for Uncertanties scopes: ', recall_unc_scope)

print('\nF1 SCORE:  ')
print('F1 score for Negations: ', f1_neg)
print('-------------------------------------------')
print('F1 score for Negation scopes: ', f1_neg_scope)
print('-------------------------------------------')
print('F1 score for Uncertanties: ', f1_unc)
print('-------------------------------------------')
print('F1 score for Uncertanties scopes: ', f1_score_unc_scope)
# Out:
# PRECISIONS:
# Precision for Negations:  0.8564356435643564
# -------------------------------------------
# Precision for Negation scopes:  0.40710382513661203
# -------------------------------------------
# Precision for Uncertanties:  0.8662420382165605
# -------------------------------------------
# Precision for Uncertanties scopes:  0.2922077922077922
#
# RECALL:
# Recall for Negations:  0.3191489361702128
# -------------------------------------------
# Recall for Negation scopes:  0.17551963048498845
# -------------------------------------------
# Reall for Uncertanties:  0.26666666666666666
# -------------------------------------------
# Recall for Uncertanties scopes:  0.18181818181818182
#
# F1 SCORE:
# F1 score for Negations:  0.46501209569035035
# -------------------------------------------
# F1 score for Negation scopes:  0.24528608406528543
# -------------------------------------------
# F1 score for Uncertanties:  0.4077961019490255
# -------------------------------------------
# F1 score for Uncertanties scopes:  0.224159402241594
